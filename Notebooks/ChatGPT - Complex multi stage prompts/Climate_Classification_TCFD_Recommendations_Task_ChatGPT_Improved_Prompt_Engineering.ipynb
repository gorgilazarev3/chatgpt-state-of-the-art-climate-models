# %% [markdown]
# # Climate-related classification tasks on ChatGPT - using techniques for better prompt engineering
# <hr>
# <h3>In this Notebook we have used various techniques for better prompt engineering in order to get better results, including chaining of prompts, using different patterns for prompts like <i>"The Persona Pattern"</i> where which enables
# the model to take a certain point of view or role, in our
# case, a climate, sustainability, and environmental expert; <i>“The Fact Check List Pattern”</i>, which instructs the model
# to output the most important points of a text and then use
# those points as the input in a follow-up prompt and the
# <i>“Reflection Pattern”</i> in which the model is asked to
# explain the reasoning behind its response.</h3>
# <h3>For that purpose, in this script we have created a function that connects to the OpenAI API using the API key and sends the data and the prompts provided to ChatGPT in batch, in chosen batch size. Additionally, a function that chains prompts was also created such that it receives the first prompt and forwards it as input in the second prompt.</h3>
# <h3>In order to be able to run the scripts and the tasks, first the OpenAI key needs to be set.</h3>
# <h3>Because this key is a secret and gives access to your OpenAI account, it should be hidden and not available in plain text to the public. It is advised to store these keys in files on your computer on on some cloud, like Google Drive where other people cannot access them and then open them in the Notebook and set the keys via variables, that way they can be protected from the public.</h3>
# <h3>In our approach, we used text files on Google Drive to store the key and we open them in the Notebook, set the appropriate variable and then use the variable to set the key.</h3>
# <hr>
# <h3>To use this script, you need to set your OpenAI key, to do that, if you use the same approach as us, first you need to store your key in a file and store them on Google Drive and after that only the path to the file in which the key is stored needs to be changed and the script will work.</h3>
# <h3>Alternative approaches include uploading your locally stored files to the Colab Notebook, using a GitHub repository or using alternative storage solutions.</h3>
# <h3>On the following link you can find ways to deal with your files on various storage providers: <a href="https://neptune.ai/blog/google-colab-dealing-with-files">https://neptune.ai/blog/google-colab-dealing-with-files</a></h3>
# <hr>
# <h3>Each task is structured in its own Colab Notebook and in order to get the results for a task, first the appropriate keys must be set in the Notebook and after that the whole Notebook can just be run and the results will be displayed at the end of the section, either by collapsing the section and running the cells from the whole section at once or running each cell one by one. Some steps are optional, for example saving the results in a .csv file and may be skipped.</h3>

# %%
#This code is for mounting your Google Drive to the Notebook. The path where you can access your whole Google Drive is /content/drive
#Alternatively, the Google Drive may be mounted by clicking the folder icon on the left side menu and then clicking the third icon from the
#left, the dark icon with a folder and the logo of Google Drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install scikit-llm

#If you use the same approach as us, with Google Drive, you need to change the paths to your relevant files where the keys are stored on Google Drive

with open('Here put the path to your OpenAI API key', 'r') as file1:
    key = file1.readline()

with open('Here put the path to your OpenAI organization key', 'r') as file2:
    org_key = file2.readline()



from skllm.config import SKLLMConfig

#Alternatively, you can just insert your keys as plain text in the appropriate places, but this is not advised since your keys would be visible to anyone who has access to your Notebook
#For using other approaches, please visit the link provided in the description above that instructs use and import of files from other storage solutions

SKLLMConfig.set_openai_key(key)
SKLLMConfig.set_openai_org(org_key)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting openai
#   Using cached openai-0.27.8-py3-none-any.whl (73 kB)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai) (2.27.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai) (4.65.0)
# Collecting aiohttp (from openai)
#   Downloading aiohttp-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 39.4 MB/s eta 0:00:00
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (23.1.0)
# Collecting multidict<7.0,>=4.5 (from aiohttp->openai)
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 14.1 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp->openai)
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->openai)
#   Downloading yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 28.6 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1 (from aiohttp->openai)
#   Downloading frozenlist-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 20.2 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2 (from aiohttp->openai)
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Installing collected packages: multidict, frozenlist, async-timeout, yarl, aiosignal, aiohttp, openai
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 frozenlist-1.3.3 multidict-6.0.4 openai-0.27.8 yarl-1.9.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tiktoken
#   Downloading tiktoken-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 61.5 MB/s eta 0:00:00
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2022.10.31)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (3.4)
# Installing collected packages: tiktoken
# Successfully installed tiktoken-0.4.0

# %%
import json
import time
def batch_gpt(prompt,target_texts, batch_size):
    l = len(target_texts)
    size = int(l / batch_size) + 1
    size = batch_size
    text_list = np.array_split(target_texts, 3)
    print(f"Total records {l}, number of chunks = {size}")
    rez_keys = []
    rez_vals = []
    rez = []
    for i, texts in enumerate(text_list):
        text = "\n".join(texts)
        p = prompt + text
        print("prompt", p)
        response = openai.ChatCompletion.create(
            model="gpt-3.5-turbo",
            messages=[{"role": "user", "content": p}]
        )
        r = response["choices"][0]["message"]["content"]
        print(result, r)
        rez.append(r)
        try:
            dictData= json.loads(r)
            keys = list(dictData.keys())
            values = list(dictData.values())
            rez_keys += keys
            rez_vals += values
        except:
            print("error parsing"+r)
        print(f"i={i + 1}: shape:{len(rez_keys)}")
    return rez_keys, rez_vals, rez
def batch_gpt_len(prompt,target_texts, batch_size):
    l = len(target_texts)
    rez_keys = []
    rez_vals = []
    rez = []
    i =0
    while i < l:
        text = ""
        for j in range(batch_size):
            if i<l:
                if batch_size > 1:
                    text += f"{i}. "+target_texts[i]+"\n\n"
                else:
                    text += target_texts[i]
            i += 1
        p = prompt + text
        #print(f"Prompt ({len(p)}):", p)
        # print(i, len(p))

        # try the API call and if it fails, wait 10 seconds and retry again (max 3 times)
        for j in range(6):
            try:
                response = openai.ChatCompletion.create(
                    model="gpt-3.5-turbo",
                    messages=[{"role": "user", "content": p}]
                )
                break
            except:
                print("error calling API, retrying...")
                time.sleep(10)

        r = response["choices"][0]["message"]["content"]
        rez.append(r)
        # convert r to int
        try:
            b = int(r[:1])
        except:
            b = -1
            print("error parsing"+r)
        print(i, len(p), "-", r, b, end=": ")
        # if i % 10 print
        if i % 10 == 0:
            print()
        rez_keys.append(b)
    return rez,rez_keys


def batch_gpt_chained(prompt,chained_prompt,target_texts, batch_size):
    l = len(target_texts)
    rez_keys = []
    rez_vals = []
    rez = []
    i =0
    while i < l:
        text = ""
        for j in range(batch_size):
            if i<l:
                if batch_size > 1:
                    text += f"{i}. "+target_texts[i]+"\n\n"
                else:
                    text += target_texts[i]
            i += 1
        p = prompt + text
        #print(f"Prompt ({len(p)}):", p)
        # print(i, len(p))

        # try the API call and if it fails, wait 10 seconds and retry again (max 3 times)
        for j in range(6):
            try:
                response = openai.ChatCompletion.create(
                    model="gpt-3.5-turbo",
                    messages=[{"role": "user", "content": p}]
                )
                break
            except:
                print("error calling API, retrying...")
                time.sleep(10)

        r1 = response["choices"][0]["message"]["content"]
        try:
            response = openai.ChatCompletion.create(
                model="gpt-3.5-turbo",
                messages=[{"role": "user", "content": chained_prompt + text}]
            )
        except:
            print("error calling API, retrying...")
            time.sleep(10)

        r = response["choices"][0]["message"]["content"]
        rez.append(r)
        # convert r to int
        try:
            b = int(r[:1])
        except:
            b = -1
            print("error parsing"+r)
        print(i, len(p), "-", r, b, end=": ")
        # if i % 10 print
        if i % 10 == 0:
            print()
        rez_keys.append(b)
    return rez,rez_keys



def batch_gpt_resp_as_part_prompt(prompt,chained_prompt,target_texts, batch_size):
    l = len(target_texts)
    rez_keys = []
    rez_vals = []
    rez = []
    summarized_points = []
    i =0
    while i < l:
        text = ""
        for j in range(batch_size):
            if i<l:
                if batch_size > 1:
                    text += f"{i}. "+target_texts[i]+"\n\n"
                else:
                    text += target_texts[i]
            i += 1
        p = prompt + text
        #print(f"Prompt ({len(p)}):", p)
        # print(i, len(p))

        # try the API call and if it fails, wait 10 seconds and retry again (max 3 times)
        for j in range(6):
            try:
                response = openai.ChatCompletion.create(
                    model="gpt-3.5-turbo",
                    messages=[{"role": "user", "content": p}]
                )
                break
            except:
                print("error calling API, retrying...")
                time.sleep(10)

        r1 = response["choices"][0]["message"]["content"]
        summarized_points.append(r1)
        try:
            response = openai.ChatCompletion.create(
                model="gpt-3.5-turbo",
                messages=[{"role": "user", "content": chained_prompt + r1}]
            )
        except:
            print("error calling API, retrying...")
            time.sleep(10)

        r = response["choices"][0]["message"]["content"]
        rez.append(r)
        # convert r to int
        try:
            b = int(r[:1])
        except:
            b = -1
            print("error parsing"+r)
        print(i, len(p), "-", r, b, end=": ")
        # if i % 10 print
        if i % 10 == 0:
            print()
        rez_keys.append(b)
    return rez,rez_keys, summarized_points




def batch_gpt_verify_cot_prompts(start_prompt,end_prompt,target_texts, batch_size):
    l = len(target_texts)
    rez_keys = []
    rez_vals = []
    rez = []
    i =0
    while i < l:
        text = ""
        for j in range(batch_size):
            if i<l:
                if batch_size > 1:
                    text += f"{i}. "+target_texts[i]+"\n\n"
                else:
                    text += target_texts[i]
            i += 1
        p = start_prompt + text + end_prompt
        #print(f"Prompt ({len(p)}):", p)
        # print(i, len(p))

        # try the API call and if it fails, wait 10 seconds and retry again (max 3 times)
        for j in range(6):
            try:
                response = openai.ChatCompletion.create(
                    model="gpt-3.5-turbo",
                    messages=[{"role": "user", "content": p}]
                )
                break
            except:
                print("error calling API, retrying...")
                time.sleep(10)

        r = response["choices"][0]["message"]["content"]
        rez.append(r)
        # convert r to int
        try:
            parts = r.split("\"")
            i = len(parts)-2
            b = parts[i]
            b = b.lower()
            if b.startswith("yes"):
              b = 1
            else:
              b = 0
        except:
            b = -1
            print("error parsing"+r)
        # print(i, len(p), "-", r, b, end=": ")
        print(f"{i}: \| response: {r} \| result: {b}\n\n")
        # if i % 10 print
        if i % 10 == 0:
            print()
        rez_keys.append(b)
    return rez,rez_keys

# %% [markdown]
# <h1>Running the Classification of paragraphs into one of the recommended categories by the Task Force on Climate-Related Financial Disclosures (TCFD) on ChatGPT</h1>
# <h4>In this task, paragraphs are classified into one category from the TCFD Recommended categories for climate change-related texts.</h4>
# <hr>
# <h4>Classification classes:</h4>
# <h4>0 - is not climate-related</h4>
# <h4>1 - is about metrics</h4>
# <h4>2 - is about strategy</h4>
# <h4>3 - is about risk</h4>
# <h4>4 - is about governance</h4>
# <hr>
# <h4>First, the required library - datasets is loaded in order to be able to work with the dataset and the corresponding dataset is downloaded from HuggingFace and loaded into the dataset variable.</h4>

# %%
# !pip install datasets
from datasets import load_dataset

dataset = load_dataset("climatebert/tcfd_recommendations")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.13.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.22.4)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.27.1)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.65.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.2.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.4.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.8.4)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.15.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (3.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Downloading readme:   0%|          | 0.00/4.64k [00:00<?, ?B/s]
# Downloading and preparing dataset None/None to /root/.cache/huggingface/datasets/climatebert___parquet/climatebert--tcfd_recommendations-8f7123f770abbd61/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7...
# Downloading data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/360k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/132k [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/1300 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/400 [00:00<?, ? examples/s]
# Dataset parquet downloaded and prepared to /root/.cache/huggingface/datasets/climatebert___parquet/climatebert--tcfd_recommendations-8f7123f770abbd61/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label'],
#         num_rows: 1300
#     })
#     test: Dataset({
#         features: ['text', 'label'],
#         num_rows: 400
#     })
# })

# %%
dataset['test']
# Out:
# Dataset({
#     features: ['text', 'label'],
#     num_rows: 400
# })

# %% [markdown]
# <h4>After that, the paragraphs and the labels are extracted from the dataset and are loaded into a Pandas DataFrame that allows easier manipulation with the data and better visualization of the data, with tables.</h4>

# %%
data = []
for i in range(0,len(dataset['test']['text'])):
  data.append([dataset['test']['text'][i],dataset['test']['label'][i]])

print(data)
# Out:
# [['Sustainable strategy ‘red lines’ For our sustainable strategy range, we incorporate a series of proprietary ‘red lines’ in order to ensure the poorest- performing companies from an ESG perspective are not eligible for investment.', 2], ['Verizon’s environmental, health and safety management system provides a framework for identifying, controlling, and reducing the risks associated with the environments in which we operate. Besides regular management system assessments, internal and third-party compliance audits and inspections are performed annually at hundreds of facilities worldwide. The goal of these assessments is to identify and correct site-specific issues, and to educate and empower facility managers and supervisors to implement corrective actions. Verizon’s environment, health and safety efforts are directed and supported by experienced experts around the world that support our operations and facilities.', 3], ['In 2019, the Company closed a series of transactions related to the sale of its Canadian fossil fuel-based electricity generation business. A transaction with Heartland Generation Ltd., an affiliate of Energy Capital Partners, included the sale of 10 partly or fully owned natural gas-fired and coal-fired electricity generation assets located in Alberta and British Columbia. In two other separate transactions, the Company sold its 50 per cent ownership interest in the Cory Cogeneration Station to SaskPower International and its 50 per cent ownership interest in Brighton Beach Power to Ontario Power Generation.', 2], ['In December 2020, the AUC approved the Electricity Distribution and Natural Gas Distribution requests to defer the compulsory distribution rate increases which would normally come into effect on January 1, 2021 for both businesses. The rate relief was requested to defer significant distribution rate increases which would be passed onto end use customers due to the formulaic approach of rate calculations under the AUC PBR mechanism. Electricity Distribution and Natural Gas Distribution cited the current economic situation in Alberta, including the hardships faced by some end use customers due to the COVID-19 pandemic, as rationale to proceed with these interim rates. Electricity Distribution and Natural Gas Distribution are to file an application by March 1, 2021, outlining the duration of the rate freeze and collection timelines, expected deferral values including carrying costs and anticipated impacts to customers.', 2], ['Finally, there is a reputational risk linked to the possibility that oil companies may be perceived by institutions and the general public as the entities mainly responsible of the climate change. This could possibly make Eni’s shares less attractive to investment funds and individual investors who assess the risk profile of companies against their environmental and social footprint when making investment decisions.', 2], ['Ecoefficiency Eco-efficiency management provides a reduction in the consumption of natural resources, such as water and energy, thus minimizing the environmental impact, in addition to the expenses with the acquisition of said inputs. With the same goal, GHG emissions and consumption of materials were rationalized, such as: paper, toner and fuel, reducing the generation of solid waste.', 2], ['The Group and its customers are exposed to climate related events, including climate change. These events include severe storms, drought, fires, cyclones, hurricanes, floods and rising sea levels. The Group and its customers may also be exposed to other events such as geological events (including volcanic seismic activity or tsunamis), plant, animal and human diseases or a pandemic.', 2], ['Increasing income of the middle classes leads to preference for quality and luxury products as well as differentiated needs including that for personal care items. Meanwhile, urban consumers are demanding greater convenience across their lifestyle choices, better mobility and ligh ...

# %%
import pandas as pd
df = pd.DataFrame(data=data,columns=["text","label"])

# %%
df
# Out:
#                                                   text  label
# 0    Sustainable strategy ‘red lines’ For our susta...      2
# 1    Verizon’s environmental, health and safety man...      3
# 2    In 2019, the Company closed a series of transa...      2
# 3    In December 2020, the AUC approved the Electri...      2
# 4    Finally, there is a reputational risk linked t...      2
# ..                                                 ...    ...
# 395  In 2020, Banco do Brasil Foundation celebrated...      2
# 396  Climate change is producing changes in weather...      2
# 397  A sound and certain regulatory and fiscal envi...      0
# 398  Across our global workforce, 20% of Gold Field...      0
# 399  The purchase price of these raw materials and ...      0
#
# [400 rows x 2 columns]

# %% [markdown]
# <h4>The initial prompt that was sent to ChatGPT was the following: "You are the sustainability, environment, and climate change expert. Read the following paragraph and extract the most important points from the text and return only the points and their explanations:"</h4>
# <h4>After the response was received, the response was then used as the input for the second prompt in which ChatGPT is instructed to perform the classification. The chained prompt was the following: "Read the following points and answer only with the overall class of which all points are summarized without any explanations. Answer only with 0 if the text is not climate-related, answer only with 1 if the text is about metrics for sustainability, environment, and climate change, answer only with 2 if the text is about strategy for sustainability, environment, and climate change, answer only with 3 if the text is about risk for sustainability, environment, and climate change and answer only with 4 if the text is about governance for sustainability, environment, and climate change:"</h4>
# <hr>
# <h4>The results were received both in a numerical - categorical and textual representation</h4>

# %%
prompt = 'You are the sustainability, environment, and climate change expert. Read the following paragraph and extract the most important points from the text and return only the points and their explanations: \n\n'
chain_prompt = 'Read the following points and answer only with the overall class of which all points are summarized without any explanations. Answer only with 0 if the text is not climate-related, answer only with 1 if the text is about metrics for sustainability, environment, and climate change, answer only with 2 if the text is about strategy for sustainability, environment, and climate change, answer only with 3 if the text is about risk for sustainability, environment, and climate change and answer only with 4 if the text is about governance for sustainability, environment, and climate change: \n\n'
texts = df["text"].to_list()
summarized_points = []
rez, rez_keys, summarized_points = batch_gpt_resp_as_part_prompt(prompt,chain_prompt, texts, 1)
# Out:
# 1 431 - 2 2: 2 889 - 3 3: 3 818 - 0 0: 4 1131 - 4 4: 5 621 - 3 3: 6 590 - 1 1: 7 587 - 3 3: 8 635 - 1. 0
# 2. 0
# 3. 1 1: 9 731 - 4 4: 10 506 - 1 1:
# 11 795 - 4 4: 12 462 - 3 3: 13 474 - 1 1: 14 708 - 3 (risk for sustainability, environment, and climate change) 3: 15 428 - 1 1: 16 637 - 0 0: 17 487 - 1 1: 18 648 - 1 1: 19 571 - 3 3: 20 402 - 3 3:
# 21 878 - 3 3: 22 637 - 0 0: 23 913 - 1 (metrics for sustainability, environment, and climate change) 1: 24 858 - 1 1: 25 813 - 3 3: error calling API, retrying...
# error parsing- Point: Increased severity/frequency of extreme weather events
# - Explanation: Refers to the worsening and more frequent occurrence of natural disasters such as hurricanes, floods, and wildfires.
#
# - Point: Loss or impairment of key manufacturing sites
# - Explanation: Refers to the damage or destruction of facilities where products are manufactured, leading to disruptions in supply chains and production.
#
# - Point: Inability to procure sufficient raw materials
# - Explanation: Refers to the difficulty in obtaining necessary resources due to disruptions in transportation or other barriers.
#
# - Point: Disruption to transportation of raw materials or finished goods
# - Explanation: Refers to difficulties in transporting necessary materials and products, leading to delays and potential shortages.
#
# - Point: Need for effective management and remedy in response to extreme events
# - Explanation: Highlighting the importance of taking swift and appropriate action to recover from natural disasters and other events that disrupt operations.
# 26 564 - - Point: Increased severity/frequency of extreme weather events
# - Explanation: Refers to the worsening and more frequent occurrence of natural disasters such as hurricanes, floods, and wildfires.
#
# - Point: Loss or impairment of key manufacturing sites
# - Explanation: Refers to the damage or destruction of facilities where products are manufactured, leading to disruptions in supply chains and production.
#
# - Point: Inability to procure sufficient raw materials
# - Explanation: Refers to the difficulty in obtaining necessary resources due to disruptions in transportation or other barriers.
#
# - Point: Disruption to transportation of raw materials or finished goods
# - Explanation: Refers to difficulties in transporting necessary materials and products, leading to delays and potential shortages.
#
# - Point: Need for effective management and remedy in response to extreme events
# - Explanation: Highlighting the importance of taking swift and appropriate action to recover from natural disasters and other events that disrupt operations. -1: 27 513 - 2 2: 28 453 - 1 1: 29 684 - 4 4: 30 816 - 3 3:
# 31 814 - 0 0: 32 411 - 2 2: 33 510 - 2 2: 34 705 - 3 3: 35 869 - 2 2: 36 1039 - 1 1: error parsingClass 2: Metrics for sustainability, environment, and climate change.
# 37 794 - Class 2: Metrics for sustainability, environment, and climate change. -1: 38 536 - 2 2: 39 709 - 3 (risk for sustainability, environment, and climate change) 3: 40 526 - 1 1:
# 41 626 - 3 3: 42 504 - 1 1: 43 366 - 2 2: 44 781 - 2 2: 45 660 - 2 2: 46 452 - 1. (Metrics for sustainability, environment, and climate change) 1: 47 499 - 4 4: 48 759 - 3 3: 49 756 - 4 4: 50 470 - 1 1:
# 51 431 - 4 4: 52 420 - 1 1: 53 657 - 2 - Metrics for sustainability, environment, and climate change. 2: 54 526 - 1 (metrics for sustainability, environment, and climate change) 1: 55 1349 - 1 1: 56 660 - 2 (strategy for sustainability, environment, and climate change) 2: 57 624 - 3 3: 58 436 - 4 4: 59 555 - 4 4: 60 581 - 1 1:
# 61 493 - 1 1: 62 821 - 2 2: 63 573 - 3 3: 64 1594 - 3 3: 65 419 - 1 1: 66 1180 - 2 (strategy for sustainability, environment, and climate change) 2: 67 554 - 4 4: 68 457 - 3 3: 69 634 - 1 1: 70 738 - 4 4:
# 71 881 - 3 3: error calling API, retrying...
# 72 529 - 0 0: 73 1054 - 1 (climate-related) 1: 74 809 - 4 4: 75 766 - 3 3: 76 831 - 3 3: 77 1258 - 0 0: 78 583 - 2 2: 79 634 - 3 3: 80 510 - 0 0:
# 81 574 - 1 1: 82 444 - 1 1: 83 746 - 0 0: 84 513 - 2 2: 85 1594 - 4 4: 86 723 - 2 - Metrics for sustainability, environment, and climate change. 2: 87 516 - 2 2: 88 545 - 2 2: 89 961 - 3 3: 90 741 - 2 2:
# 91 913 - 0 0: 92 573 - 3 3: 93 636 - 1 1: 94 623 - 3 3: 95 552 - 3 3: 96 554 - 3 3: 97 1293 - 1. 1 (metrics for sustainability, environment, and climate change)
# 2. 1 (metrics for sustainability, environment, and climate change)
# 3. 1 (metrics for sustainability, environment, and climate change)
# 4. 1 (metrics for sustainability, environment, and climate change)
# 5. 1 (metrics for sustainability, environment, and climate change) 1: error calling API, retrying...
# 98 650 - 1 (metrics for sustainability, environment, and climate change) 1: 99 501 - 1 1: 100 941 - 1 1:
# 101 545 - 4 4: 102 727 - 1 1: 103 401 - 0 0: 104 819 - 1 1: 105 451 - 1 1: 106 875 - 4 (governance for sustainability, environment, and climate change) 4: 107 861 - 3 3: 108 808 - 4 4: 109 668 - 1 1: 110 418 - 3 3:
# 111 667 - 3 - Risk for sustainability, environment, and climate change. 3: 112 635 - 0 0: 113 4077 - 3 (risk for sustainability, environment, and climate change) 3: 114 486 - 1 1: 115 699 - 4 4: 116 541 - 1. 1: 117 1079 - 3 3: 118 717 - 3 - risk for sustainability, environment, and climate change. 3: 119 494 - 0 0: 120 637 - 0 0:
# 121 707 - 4 4: 122 481 - 1 1: 123 627 - 4 4: 124 557 - 1 1: 125 644 - 2. 2: 126 655 - 3 3: 127 1025 - 3 (Risk for sustainability, environment, and climate change) 3: 128 1097 - 3 3: 129 615 - 1 1: 130 774 - 3 (risk for sustainability, environment, and climate change) 3:
# 131 662 - 4 4: 132 362 - 2 2: 133 523 - 1. Climate-related. 1: error calling API, retrying...
# 134 548 - 3 3: 135 783 - 2 2: 136 665 - 2 2: 137 953 - 1 1: 138 618 - 3 (risk for sustainability, environment, and climate change). 3: 139 1348 - 4 4: 140 665 - 2 2:
# 141 603 - 1 1: 142 801 - 3. 3: 143 428 - 3 (risk for sustainability, environment, and climate change) 3: 144 528 - 3 3: 145 501 - 2 (metrics for sustainability, environment, and climate change) 2: 146 544 - 1 1: 147 605 - 3 3: 148 860 - 4 4: 149 663 - 4 4: 150 630 - 1 1:
# error calling API, retrying...
# 151 599 - 3 3: 152 618 - 3 3: 153 597 - 3 (risk for sustainability, environment, and climate change) 3: 154 525 - 3 3: 155 612 - 1 1: 156 772 - 1 1: 157 765 - 2 (strategy for sustainability, environment, and climate change) 2: 158 459 - 1 1: 159 840 - 2 2: 160 1198 - 4 4:
# 161 420 - 1 1: 162 598 - 4 4: 163 458 - 1 - Risk for sustainability, environment, and climate change
# 2 - Strategy for sustainability, environment, and climate change 1: 164 550 - 1 1: 165 811 - 3 3: 166 548 - 2 2: 167 2865 - 2 2: 168 679 - 3 3: 169 789 - 3 (Risk for sustainability, environment, and climate change) 3: 170 934 - 1 (not climate-related) 1:
# 171 1203 - 4 4: 172 1821 - 2 2: 173 971 - 2 2: 174 632 - 1 1: 175 465 - 1 1: 176 542 - 3 3: 177 1013 - 1 1: 178 1059 - 3 - Strategy for sustainability, environment, and climate change. 3: 179 889 - 3 3: 180 805 - 3 3:
# 181 940 - 4 4: 182 643 - 0 0: 183 770 - 4 - Governance for sustainability, environment, and climate change. 4: 184 805 - 1 (Metrics for sustainability, environment, and climate change) 1: 185 671 - 1 1: 186 688 - 1 (metrics for sustainability, environment, and climate change) 1: 187 686 - 2 2: 188 794 - 1 - metrics for sustainability, environment, and climate change. 1: 189 648 - 1 (metrics for sustainability, environment, and climate change) 1: 190 696 - 1 1:
# 191 578 - 3 3: 192 580 - 1 1: 193 531 - 1 1: 194 612 - 2 2: 195 763 - 4. Governance for sustainability, environment, and climate change. 4: 196 758 - 1 1: 197 737 - 1 1: 198 788 - 4 4: 199 513 - 1 1: 200 694 - 4 4:
# 201 644 - 2 - Metrics for sustainability, environment, and climate change. 2: 202 606 - 4 4: 203 798 - 3 - Risk for sustainability, environment, and climate change. 3: 204 1675 - 4 4: 205 1716 - 1 1: 206 918 - 1 1: 207 576 - 3 3: 208 1057 - 3 3: 209 454 - 1 1: error calling API, retrying...
# 210 583 - 1. Data reported is the same as 2018, except for Abertis Group.
# 	- This refers to the data reporting perimeter.
# 2. Diesel consumption data for gensets in Chile in 2018 is missing.
# 	- This highlights a gap in the available data.
# 3. Figure updated after Integrated Report 2018 on ETC data.
# 	- This indicates a change in the reported figure after further consolidation.
# 4. Data updated after restatement of the income statement 2018.
# 	- This refers to an update of the reported data based on a restatement of income statements.
# 5. Emissions reported based on location.
# 	- This specifies the basis for reporting emissions. 1:
# 211 439 - 4 4: 212 699 - 1. 1: 213 774 - 4 4: 214 836 - 3. Risk for sustainability, environment, and climate change. 3: 215 3067 - 3 3: 216 549 - 1 1: 217 937 - 4 4: 218 934 - 0 0: 219 567 - 3 3: 220 601 - 3 3:
# 221 712 - 1 1: 222 550 - 4 4: 223 1035 - 4 4: 224 377 - 1 1: 225 882 - 2 2: 226 398 - 1 1: 227 483 - 1 - Metrics for sustainability, environment, and climate change.
# 2 - Strategy for sustainability, environment, and climate change.
# 3 - Metrics for sustainability, environment, and climate change. 1: 228 718 - 0 0: 229 872 - 2 2: 230 860 - 3 3:
# 231 727 - 1 1: 232 634 - 4 4: 233 732 - 1 - metrics for sustainability, environment, and climate change 1: 234 1073 - 3 3: 235 574 - 3 3: 236 479 - 1 (climate-related) and 2 (strategy for sustainability, environment, and climate change) 1: 237 1334 - 4 4: 238 832 - 3 3: 239 802 - 4 4: 240 747 - 4 4:
# 241 537 - 1 1: 242 509 - 4 4: 243 794 - 2 2: 244 585 - 3 3: 245 605 - 2 2: 246 459 - 4 4: 247 580 - 2 2: 248 773 - 3 3: 249 676 - 4. 4: 250 530 - 4 4:
# 251 978 - 3 3: 252 432 - 1 1: 253 469 - 3 3: 254 1500 - 1 (metrics for sustainability, environment, and climate change) 1: 255 477 - 1 1: 256 1136 - 3 3: 257 1074 - 1 1: 258 612 - 3 3: 259 852 - 1 1: error calling API, retrying...
# error parsing- In 2019, there were 61 spills of hazardous materials at Group level.
# - 25 of these spills occurred in airports and were mostly related to AVIO fuel.
# - There are specific internal procedures in place for handling emergencies and managing environmental risks related to the handling of AVIO fuel.
# - 36 spills occurred on motorways, primarily due to accidents involving fuel spills and loss of loads.
# - There were also environmental inspections and critical events reported.
# 260 643 - - In 2019, there were 61 spills of hazardous materials at Group level.
# - 25 of these spills occurred in airports and were mostly related to AVIO fuel.
# - There are specific internal procedures in place for handling emergencies and managing environmental risks related to the handling of AVIO fuel.
# - 36 spills occurred on motorways, primarily due to accidents involving fuel spills and loss of loads.
# - There were also environmental inspections and critical events reported. -1:
# 261 1086 - 3 (Risk for sustainability, environment, and climate change) 3: 262 574 - 0 0: 263 494 - 1 1: 264 798 - 1 1: 265 597 - 1 (metrics for sustainability, environment, and climate change) 1: 266 570 - 2 (strategy for sustainability, environment, and climate change) 2: 267 505 - 2 (strategy for sustainability, environment, and climate change) 2: 268 539 - 3 3: 269 634 - 0 0: 270 1358 - 3 3:
# 271 425 - 3 (risk for sustainability, environment, and climate change) 3: 272 575 - 1 1: 273 618 - 3 3: 274 912 - 0 0: 275 627 - 2 2: 276 1104 - 1 1: 277 687 - 1 1: 278 738 - 1 1: 279 790 - 4 4: 280 579 - 3 3:
# 281 998 - 2 2: 282 811 - 1 1: 283 575 - 0 0: 284 537 - 1 1: 285 889 - 0 0: 286 1879 - 4 4: 287 569 - 3 3: 288 832 - 0 (not climate-related) 0: 289 640 - 2 2: 290 1218 - 4 4:
# error calling API, retrying...
# 291 515 - 1 1: 292 638 - 1 1: 293 803 - 3 3: 294 555 - 1 1: 295 876 - 2 2: 296 466 - 2 2: 297 448 - 1 1: 298 506 - 1 1: 299 656 - 1 - metrics for sustainability, environment, and climate change. 1: 300 1196 - 3 3:
# 301 647 - 0 0: 302 567 - 3 - risk for sustainability, environment, and climate change. 3: 303 926 - 3 (risk for sustainability, environment, and climate change) 3: 304 820 - 1 1: 305 1116 - 0 0: 306 661 - 2 2: 307 767 - 2 2: 308 432 - 2 2: 309 617 - 1 1: 310 626 - 1 - Metrics for sustainability, environment, and climate change (specifically, measures taken to reduce investment in coal) 1:
# 311 1056 - 3 3: 312 939 - 3 3: 313 519 - 3 3: 314 670 - 2 2: 315 646 - 1 1: 316 446 - 1 1: 317 752 - 3 - The text is about risk for sustainability, environment, and climate change. 3: 318 1155 - 4 4: 319 1853 - 4 4: 320 991 - 3 3:
# 321 446 - 1 1: 322 914 - 2 2: 323 640 - 2 2: 324 539 - 2 (strategy for sustainability, environment, and climate change) 2: 325 568 - 1 (metrics for sustainability, environment, and climate change) 1: 326 468 - 1 1: 327 544 - 0 (not climate-related) 0: 328 609 - 2 2: 329 419 - 4 4: 330 852 - 4 4:
# 331 437 - 2 2: 332 1292 - 3 3: 333 645 - 1 1: 334 463 - 3 (risk for sustainability, environment, and climate change) 3: 335 1950 - 0 0: 336 4167 - 3 3: 337 474 - 0 0: 338 664 - 3 3: 339 597 - 1 1: error calling API, retrying...
# 340 673 - 3 3:
# 341 561 - 3 3: 342 638 - 1 1: 343 509 - 2 2: 344 719 - 3 3: 345 486 - 1 1: 346 586 - 3 3: 347 658 - 0 0: 348 1941 - 3 3: 349 545 - 1 1: 350 821 - 2 2:
# 351 1161 - 1. Overall class: Governance for sustainability, environment, and climate change. 1: 352 1584 - 4 4: 353 686 - 3 3: 354 479 - 4 4: 355 746 - 3 3: 356 509 - 1 1: 357 517 - 2 2: 358 570 - 0 0: 359 704 - 0 0: 360 597 - 3 3:
# 361 759 - 1 1: 362 567 - 3 - Risk for sustainability, environment, and climate change. 3: 363 666 - 3 3: 364 470 - 4 4: 365 658 - 1 1: 366 957 - 1 1: 367 1012 - 4 4: 368 925 - 3 3: 369 566 - 2 2: 370 513 - 2 2:
# 371 711 - 3. 3: 372 382 - 0 0: 373 940 - 2 2: 374 619 - 3 3: error parsingOverall class: 1
# 375 630 - Overall class: 1 -1: 376 1140 - 0 0: 377 536 - 3 3: 378 689 - 3 3: 379 546 - 3 3: 380 616 - 3 3:
# 381 529 - 1 1: 382 719 - 1 1: 383 522 - 4 4: 384 903 - 0 0: 385 656 - 1 (related to governance, as it involves the request for a report by shareholders) 1: 386 689 - 2 2: 387 729 - 0 0: 388 560 - 2 - metrics for sustainability, environment, and climate change. 2: 389 582 - 3 (risk for sustainability, environment, and climate change) 3: 390 485 - 1 1:
# 391 540 - 1 1: 392 515 - 2 2: 393 555 - 1 1: 394 504 - 0 (not climate-related) 0: 395 423 - 2 2: 396 531 - 1 1: 397 1070 - 1 1: error parsingto investment
# 0 (not climate-related)
# 398 569 - to investment
# 0 (not climate-related) -1: 399 933 - 1 1: 400 960 - 0 0:

# %% [markdown]
# <h4>The predictions that are received, are stored in a variable, then they are stored both in numerical and textual representations in a Pandas DataFrame to further be compared and evaluated.</h4>

# %%
rez
# Out:
# ['2',
#  '3',
#  '0',
#  '4',
#  '3',
#  '1',
#  '3',
#  '1. 0\n2. 0\n3. 1',
#  '4',
#  '1',
#  '4',
#  '3',
#  '1',
#  '3 (risk for sustainability, environment, and climate change)',
#  '1',
#  '0',
#  '1',
#  '1',
#  '3',
#  '3',
#  '3',
#  '0',
#  '1 (metrics for sustainability, environment, and climate change)',
#  '1',
#  '3',
#  '- Point: Increased severity/frequency of extreme weather events\n- Explanation: Refers to the worsening and more frequent occurrence of natural disasters such as hurricanes, floods, and wildfires.\n\n- Point: Loss or impairment of key manufacturing sites\n- Explanation: Refers to the damage or destruction of facilities where products are manufactured, leading to disruptions in supply chains and production.\n\n- Point: Inability to procure sufficient raw materials\n- Explanation: Refers to the difficulty in obtaining necessary resources due to disruptions in transportation or other barriers.\n\n- Point: Disruption to transportation of raw materials or finished goods\n- Explanation: Refers to difficulties in transporting necessary materials and products, leading to delays and potential shortages.\n\n- Point: Need for effective management and remedy in response to extreme events\n- Explanation: Highlighting the importance of taking swift and appropriate action to recover from natural disasters and other events that disrupt operations.',
#  '2',
#  '1',
#  '4',
#  '3',
#  '0',
#  '2',
#  '2',
#  '3',
#  '2',
#  '1',
#  'Class 2: Metrics for sustainability, environment, and climate change.',
#  '2',
#  '3 (risk for sustainability, environment, and climate change)',
#  '1',
#  '3',
#  '1',
#  '2',
#  '2',
#  '2',
#  '1. (Metrics for sustainability, environment, and climate change)',
#  '4',
#  '3',
#  '4',
#  '1',
#  '4',
#  '1',
#  '2 - Metrics for sustainability, environment, and climate change.',
#  '1 (metrics for sustainability, environment, and climate change)',
#  '1',
#  '2 (strategy for sustainability, environment, and climate change)',
#  '3',
#  '4',
#  '4',
#  '1',
#  '1',
#  '2',
#  '3',
#  '3',
#  '1',
#  '2 (strategy for sustainability, environment, and climate change)',
#  '4',
#  '3',
#  '1',
#  '4',
#  '3',
#  '0',
#  '1 (climate-related)',
#  '4',
#  '3',
#  '3',
#  '0',
#  '2',
#  '3',
#  '0',
#  '1',
#  '1',
#  '0',
#  '2',
#  '4',
#  '2 - Metrics for sustainability, environment, and climate change.',
#  '2',
#  '2',
#  '3',
#  '2',
#  '0',
#  '3',
#  '1',
#  '3',
#  '3',
#  '3',
#  '1. 1 (metrics for sustainability, environment, and climate change) \n2. 1 (metrics for sustainability, environment, and climate change)\n3. 1 (metrics for sustainability, environment, and climate change)\n4. 1 (metrics for sustainability, environment, and climate change)\n5. 1 (metrics for sustainability, environment, and climate change)',
#  '1 (metrics for sustainability, environment, and climate change)',
#  '1',
#  '1',
#  '4',
#  '1',
#  '0',
#  '1',
#  '1',
#  '4 (governance for sustainability, environment, and climate change)',
#  '3',
#  '4',
#  '1',
#  '3',
#  '3 - Risk for sustainability, environment, and climate change.',
#  '0',
#  '3 (risk for sustainability, environment, and climate change)',
#  '1',
#  '4',
#  '1.',
#  '3',
#  '3 - risk for sustainability, environment, and climate change.',
#  '0',
#  '0',
#  '4',
#  '1',
#  '4',
#  '1',
#  '2.',
#  '3',
#  '3 (Risk for sustainability, environment, and climate change)',
#  '3',
#  '1',
#  '3 (risk for sustainability, environment, and climate change)',
#  '4',
#  '2',
#  '1. Climate-related.',
#  '3',
#  '2',
#  '2',
#  '1',
#  '3 (risk for sustainability, environment, and climate change).',
#  '4',
#  '2',
#  '1',
#  '3.',
#  '3 (risk for sustainability, environment, and climate change)',
#  '3',
#  '2 (metrics for sustainability, environment, and climate change)',
#  '1',
#  '3',
#  '4',
#  '4',
#  '1',
#  '3',
#  '3',
#  '3 (risk for sustainability, environment, and climate change)',
#  '3',
#  '1',
#  '1',
#  '2 (strategy for sustainability, environment, and climate change)',
#  '1',
#  '2',
#  '4',
#  '1',
#  '4',
#  '1 - Risk for sustainability, environment, and climate change\n2 - Strategy for sustainability, environment, and climate change',
#  '1',
#  '3',
#  '2',
#  '2',
#  '3',
#  '3 (Risk for sustainability, environment, and climate change)',
#  '1 (not climate-related)',
#  '4',
#  '2',
#  '2',
#  '1',
#  '1',
#  '3',
#  '1',
#  '3 - Strategy for sustainability, environment, and climate change.',
#  '3',
#  '3',
#  '4',
#  '0',
#  '4 - Governance for sustainability, environment, and climate change.',
#  '1 (Metrics for sustainability, environment, and climate change)',
#  '1',
#  '1 (metrics for sustainability, environment, and climate change)',
#  '2',
#  '1 - metrics for sustainability, environment, and climate change.',
#  '1 (metrics for sustainability, environment, and climate change)',
#  '1',
#  '3',
#  '1',
#  '1',
#  '2',
#  '4. Governance for sustainability, environment, and climate change.',
#  '1',
#  '1',
#  '4',
#  '1',
#  '4',
#  '2 - Metrics for sustainability, environment, and climate change.',
#  '4',
#  '3 - Risk for sustainability, environment, and climate change.',
#  '4',
#  '1',
#  '1',
#  '3',
#  '3',
#  '1',
#  '1. Data reported is the same as 2018, except for Abertis Group.\n\t- This refers to the data reporting perimeter.\n2. Diesel consumption data for gensets in Chile in 2018 is missing.\n\t- This highlights a gap in the available data.\n3. Figure updated after Integrated Report 2018 on ETC data.\n\t- This indicates a change in the reported figure after further consolidation.\n4. Data updated after restatement of the income statement 2018.\n\t- This refers to an update of the reported data based on a restatement of income statements.\n5. Emissions reported based on location. \n\t- This specifies the basis for reporting emissions.',
#  '4',
#  '1.',
#  '4',
#  '3. Risk for sustainability, environment, and climate change.',
#  '3',
#  '1',
#  '4',
#  '0',
#  '3',
#  '3',
#  '1',
#  '4',
#  '4',
#  '1',
#  '2',
#  '1',
#  '1 - Metrics for sustainability, environment, and climate change. \n2 - Strategy for sustainability, environment, and climate change. \n3 - Metrics for sustainability, environment, and climate change.',
#  '0',
#  '2',
#  '3',
#  '1',
#  '4',
#  '1 - metrics for sustainability, environment, and climate change',
#  '3',
#  '3',
#  '1 (climate-related) and 2 (strategy for sustainability, environment, and climate change)',
#  '4',
#  '3',
#  '4',
#  '4',
#  '1',
#  '4',
#  '2',
#  '3',
#  '2',
#  '4',
#  '2',
#  '3',
#  '4.',
#  '4',
#  '3',
#  '1',
#  '3',
#  '1 (metrics for sustainability, environment, and climate change)',
#  '1',
#  '3',
#  '1',
#  '3',
#  '1',
#  '- In 2019, there were 61 spills of hazardous materials at Group level.\n- 25 of these spills occurred in airports and were mostly related to AVIO fuel.\n- There are specific internal procedures in place for handling emergencies and managing environmental risks related to the handling of AVIO fuel.\n- 36 spills occurred on motorways, primarily due to accidents involving fuel spills and loss of loads.\n- There were also environmental inspections and critical events reported.',
#  '3 (Risk for sustainability, environment, and climate change)',
#  '0',
#  '1',
#  '1',
#  '1 (metrics for sustainability, environment, and climate change)',
#  '2 (strategy for sustainability, environment, and climate change)',
#  '2 (strategy for sustainability, environment, and climate change)',
#  '3',
#  '0',
#  '3',
#  '3 (risk for sustainability, environment, and climate change)',
#  '1',
#  '3',
#  '0',
#  '2',
#  '1',
#  '1',
#  '1',
#  '4',
#  '3',
#  '2',
#  '1',
#  '0',
#  '1',
#  '0',
#  '4',
#  '3',
#  '0 (not climate-related)',
#  '2',
#  '4',
#  '1',
#  '1',
#  '3',
#  '1',
#  '2',
#  '2',
#  '1',
#  '1',
#  '1 - metrics for sustainability, environment, and climate change.',
#  '3',
#  '0',
#  '3 - risk for sustainability, environment, and climate change.',
#  '3 (risk for sustainability, environment, and climate change)',
#  '1',
#  '0',
#  '2',
#  '2',
#  '2',
#  '1',
#  '1 - Metrics for sustainability, environment, and climate change (specifically, measures taken to reduce investment in coal)',
#  '3',
#  '3',
#  '3',
#  '2',
#  '1',
#  '1',
#  '3 - The text is about risk for sustainability, environment, and climate change.',
#  '4',
#  '4',
#  '3',
#  '1',
#  '2',
#  '2',
#  '2 (strategy for sustainability, environment, and climate change)',
#  '1 (metrics for sustainability, environment, and climate change)',
#  '1',
#  '0 (not climate-related)',
#  '2',
#  '4',
#  '4',
#  '2',
#  '3',
#  '1',
#  '3 (risk for sustainability, environment, and climate change)',
#  '0',
#  '3',
#  '0',
#  '3',
#  '1',
#  '3',
#  '3',
#  '1',
#  '2',
#  '3',
#  '1',
#  '3',
#  '0',
#  '3',
#  '1',
#  '2',
#  '1. Overall class: Governance for sustainability, environment, and climate change.',
#  '4',
#  '3',
#  '4',
#  '3',
#  '1',
#  '2',
#  '0',
#  '0',
#  '3',
#  '1',
#  '3 - Risk for sustainability, environment, and climate change.',
#  '3',
#  '4',
#  '1',
#  '1',
#  '4',
#  '3',
#  '2',
#  '2',
#  '3.',
#  '0',
#  '2',
#  '3',
#  'Overall class: 1',
#  '0',
#  '3',
#  '3',
#  '3',
#  '3',
#  '1',
#  '1',
#  '4',
#  '0',
#  '1 (related to governance, as it involves the request for a report by shareholders)',
#  '2',
#  '0',
#  '2 - metrics for sustainability, environment, and climate change.',
#  '3 (risk for sustainability, environment, and climate change)',
#  '1',
#  '1',
#  '2',
#  '1',
#  '0 (not climate-related)',
#  '2',
#  '1',
#  '1',
#  'to investment \n0 (not climate-related)',
#  '1',
#  '0']

# %%
rez_keys
# Out:
# [2,
#  3,
#  0,
#  4,
#  3,
#  1,
#  3,
#  1,
#  4,
#  1,
#  4,
#  3,
#  1,
#  3,
#  1,
#  0,
#  1,
#  1,
#  3,
#  3,
#  3,
#  0,
#  1,
#  1,
#  3,
#  -1,
#  2,
#  1,
#  4,
#  3,
#  0,
#  2,
#  2,
#  3,
#  2,
#  1,
#  -1,
#  2,
#  3,
#  1,
#  3,
#  1,
#  2,
#  2,
#  2,
#  1,
#  4,
#  3,
#  4,
#  1,
#  4,
#  1,
#  2,
#  1,
#  1,
#  2,
#  3,
#  4,
#  4,
#  1,
#  1,
#  2,
#  3,
#  3,
#  1,
#  2,
#  4,
#  3,
#  1,
#  4,
#  3,
#  0,
#  1,
#  4,
#  3,
#  3,
#  0,
#  2,
#  3,
#  0,
#  1,
#  1,
#  0,
#  2,
#  4,
#  2,
#  2,
#  2,
#  3,
#  2,
#  0,
#  3,
#  1,
#  3,
#  3,
#  3,
#  1,
#  1,
#  1,
#  1,
#  4,
#  1,
#  0,
#  1,
#  1,
#  4,
#  3,
#  4,
#  1,
#  3,
#  3,
#  0,
#  3,
#  1,
#  4,
#  1,
#  3,
#  3,
#  0,
#  0,
#  4,
#  1,
#  4,
#  1,
#  2,
#  3,
#  3,
#  3,
#  1,
#  3,
#  4,
#  2,
#  1,
#  3,
#  2,
#  2,
#  1,
#  3,
#  4,
#  2,
#  1,
#  3,
#  3,
#  3,
#  2,
#  1,
#  3,
#  4,
#  4,
#  1,
#  3,
#  3,
#  3,
#  3,
#  1,
#  1,
#  2,
#  1,
#  2,
#  4,
#  1,
#  4,
#  1,
#  1,
#  3,
#  2,
#  2,
#  3,
#  3,
#  1,
#  4,
#  2,
#  2,
#  1,
#  1,
#  3,
#  1,
#  3,
#  3,
#  3,
#  4,
#  0,
#  4,
#  1,
#  1,
#  1,
#  2,
#  1,
#  1,
#  1,
#  3,
#  1,
#  1,
#  2,
#  4,
#  1,
#  1,
#  4,
#  1,
#  4,
#  2,
#  4,
#  3,
#  4,
#  1,
#  1,
#  3,
#  3,
#  1,
#  1,
#  4,
#  1,
#  4,
#  3,
#  3,
#  1,
#  4,
#  0,
#  3,
#  3,
#  1,
#  4,
#  4,
#  1,
#  2,
#  1,
#  1,
#  0,
#  2,
#  3,
#  1,
#  4,
#  1,
#  3,
#  3,
#  1,
#  4,
#  3,
#  4,
#  4,
#  1,
#  4,
#  2,
#  3,
#  2,
#  4,
#  2,
#  3,
#  4,
#  4,
#  3,
#  1,
#  3,
#  1,
#  1,
#  3,
#  1,
#  3,
#  1,
#  -1,
#  3,
#  0,
#  1,
#  1,
#  1,
#  2,
#  2,
#  3,
#  0,
#  3,
#  3,
#  1,
#  3,
#  0,
#  2,
#  1,
#  1,
#  1,
#  4,
#  3,
#  2,
#  1,
#  0,
#  1,
#  0,
#  4,
#  3,
#  0,
#  2,
#  4,
#  1,
#  1,
#  3,
#  1,
#  2,
#  2,
#  1,
#  1,
#  1,
#  3,
#  0,
#  3,
#  3,
#  1,
#  0,
#  2,
#  2,
#  2,
#  1,
#  1,
#  3,
#  3,
#  3,
#  2,
#  1,
#  1,
#  3,
#  4,
#  4,
#  3,
#  1,
#  2,
#  2,
#  2,
#  1,
#  1,
#  0,
#  2,
#  4,
#  4,
#  2,
#  3,
#  1,
#  3,
#  0,
#  3,
#  0,
#  3,
#  1,
#  3,
#  3,
#  1,
#  2,
#  3,
#  1,
#  3,
#  0,
#  3,
#  1,
#  2,
#  1,
#  4,
#  3,
#  4,
#  3,
#  1,
#  2,
#  0,
#  0,
#  3,
#  1,
#  3,
#  3,
#  4,
#  1,
#  1,
#  4,
#  3,
#  2,
#  2,
#  3,
#  0,
#  2,
#  3,
#  -1,
#  0,
#  3,
#  3,
#  3,
#  3,
#  1,
#  1,
#  4,
#  0,
#  1,
#  2,
#  0,
#  2,
#  3,
#  1,
#  1,
#  2,
#  1,
#  0,
#  2,
#  1,
#  1,
#  -1,
#  1,
#  0]

# %%
df['gpt-label'] = rez_keys

# %%
df['gpt-explanations'] = rez

# %%
df
# Out:
#                                                   text  label  gpt-label  \
# 0    Sustainable strategy ‘red lines’ For our susta...      2          2
# 1    Verizon’s environmental, health and safety man...      3          3
# 2    In 2019, the Company closed a series of transa...      2          0
# 3    In December 2020, the AUC approved the Electri...      2          4
# 4    Finally, there is a reputational risk linked t...      2          3
# ..                                                 ...    ...        ...
# 395  In 2020, Banco do Brasil Foundation celebrated...      2          1
# 396  Climate change is producing changes in weather...      2          1
# 397  A sound and certain regulatory and fiscal envi...      0         -1
# 398  Across our global workforce, 20% of Gold Field...      0          1
# 399  The purchase price of these raw materials and ...      0          0
#
#                             gpt-explanations
# 0                                          2
# 1                                          3
# 2                                          0
# 3                                          4
# 4                                          3
# ..                                       ...
# 395                                        1
# 396                                        1
# 397  to investment \n0 (not climate-related)
# 398                                        1
# 399                                        0
#
# [400 rows x 4 columns]

# %% [markdown]
# <h4>The labels that couldn't be automatically mapped were mapped manually by observing their textual counterparts and seeing where they belong.</h4>

# %%
df['gpt-label'].value_counts()
# Out:
#  1    126
#  3    110
#  2     65
#  4     58
#  0     36
# -1      5
# Name: gpt-label, dtype: int64

# %%
df[df['gpt-label']==-1]
# Out:
#                                                   text  label  gpt-label  \
# 25   2 Increased severity/frequency of extreme weat...      2         -1
# 36   BB DTVM, by strategic direction, performs exte...      3         -1
# 259  At Group level, in 2019 there were 61 spills o...      3         -1
# 374  Report a description of how their investment p...      2         -1
# 397  A sound and certain regulatory and fiscal envi...      0         -1
#
#                                       gpt-explanations
# 25   - Point: Increased severity/frequency of extre...
# 36   Class 2: Metrics for sustainability, environme...
# 259  - In 2019, there were 61 spills of hazardous m...
# 374                                   Overall class: 1
# 397            to investment \n0 (not climate-related)

# %%
df['gpt-label'] = df['gpt-label'].replace(-1,3)

# %%
df['gpt-label'].value_counts()
# Out:
# 1    126
# 3    115
# 2     65
# 4     58
# 0     36
# Name: gpt-label, dtype: int64

# %% [markdown]
# <h4>The received summarized points were then stored in the DataFrame, such that they can be used as input in the Scikit LLM library</h4>

# %%
summarized_points
# Out:
# ["Points:\n1. Sustainable strategy range\n2. Proprietary 'red lines'\n3. Ensuring poorest-performing companies not eligible for investment\n\nExplanation:\n1. The text mentions a sustainable strategy range, which suggests that the company in question has a focus on sustainability and is implementing strategies to achieve this goal.\n2. The company uses proprietary 'red lines,' or criteria, to determine which companies are eligible for investment. These criteria likely focus on environmental, social, and governance (ESG) performance, which are important markers of sustainability.\n3. By excluding the poorest-performing companies from investment, the company is prioritizing sustainability and sending a message that it takes ESG factors seriously. This can help drive positive change within the broader investment community and promote better practices among companies.",
#  "Points:\n1. Verizon has an environmental, health, and safety management system \n2. The system identifies, controls, and reduces risks associated with the environment \n3. Regular management system assessments are conducted \n4. Internal and third-party compliance audits and inspections are performed \n5. The goal is to identify and correct site-specific issues \n6. Efforts are directed and supported by experienced experts worldwide \n7. Verizon aims to educate and empower facility managers and supervisors to implement corrective actions. \n\nExplanation:\n1. Verizon has a comprehensive system in place to manage its environmental, health, and safety risks. \n2. The system aims to identify potential risks and create strategies to reduce them. \n3. The company conducts regular assessments to ensure the system is working properly. \n4. To verify compliance performance, the company conducts both internal and third-party audits and inspections. \n5. The goal of these assessments is to identify and correct any issues that are specific to each facility. \n6. Experienced experts support Verizon's environmental efforts worldwide. \n7. Verizon aims to educate and empower facility managers and supervisors to implement corrective actions, and improve the overall effectiveness of the management system.",
#  "Points:\n- The Company sold its Canadian fossil fuel-based electricity generation business in 2019 \n- The sale included 10 natural gas-fired and coal-fired electricity generation assets in Alberta and British Columbia \n- The Company also sold its 50 per cent ownership interest in the Cory Cogeneration Station to SaskPower International\n- Additionally, the Company sold its 50 per cent ownership interest in Brighton Beach Power to Ontario Power Generation. \n\nExplanation: \nThe text highlights the Company's transactions related to the sale of its Canadian fossil fuel-based electricity generation business. The sale included 10 natural gas-fired and coal-fired electricity generation assets located in Alberta and British Columbia. In addition, the company sold its 50 per cent stakeholdership in the Cory Cogeneration Station to SaskPower International and its 50 per cent ownership interest in Brighton Beach Power to Ontario Power Generation.",
#  'Points:\n- AUC approved deferral of distribution rate increases for Electricity Distribution and Natural Gas Distribution requested in December 2020\n- Rate relief requested due to formulaic approach of rate calculations under AUC PBR mechanism\n- Current economic situation and COVID-19 pandemic cited as rationale for deferral\n- Application to be filed by March 1, 2021 outlining duration of rate freeze, collection timelines, deferral values, carrying costs, and anticipated impacts to customers. \n\nExplanation:\nThe AUC (Alberta Utilities Commission) approved a deferral of compulsory distribution rate increases requested by Electricity Distribution and Natural Gas Distribution in December 2020. This relief was requested due to the formulaic approach of rate calculations under the AUC PBR (Performance-Based Regulation) mechanism, which would have resulted in significant rate increases passed onto end use customers. The current economic situation in Alberta, including the COVID-19 pandemic, were cited as reasons for the deferral. The companies are required to file an application by March 1, 2021 outlining the details of the rate freeze, including duration, collection timelines, deferral values, carrying costs, and anticipated impacts on customers.',
#  "- Reputational risk for oil companies \n- Possibility of being perceived as mainly responsible for climate change \n- Could result in Eni's shares being less attractive to investors who assess companies' risk profile based on environmental and social footprint",
#  '- Eco-efficiency management reduces consumption of natural resources (water and energy) to minimize environmental impact and expenses\n- GHG emissions and material consumption (such as paper, toner, and fuel) are rationalized for the same goal\n- Solid waste generation is reduced as a result.',
#  '1. The Group and its customers are exposed to climate related events\nExplanation: Climate related events such as severe storms, drought, fires, cyclones, hurricanes, floods and rising sea levels can affect the Group and its customers. \n\n2. Other events such as geological events, diseases or pandemics may also impact the Group and its customers.\nExplanation: The Group and its customers may also be exposed to events such as geological events (including volcanic seismic activity or tsunamis), plant, animal, and human diseases, or a pandemic.',
#  'Points:\n1. Increasing income of middle classes leads to preference for quality and luxury products and personal care items.\nExplanation: As income of middle classes is increasing, their preferences are shifting towards quality products and personal care items.\n\n2. Urban consumers are demanding greater convenience, mobility, and smart devices.\nExplanation: Urban consumers are looking for convenient options in their lifestyle choices, including better mobility and smart devices.\n\n3. Growing demand for specialty chemical products presents opportunities for sustainable growth. \nExplanation: The increasing demand for specialty chemical products in response to changing preferences presents an opportunity for sustainable growth.',
#  '- Verizon recognizes the importance of operating responsibly and minimizing their environmental impact for long-term success\n- Building a better future involves making climate awareness "business as usual"\n- Board oversight and management governance structures are evolving to include regular assessment and discussion of climate-related risks and opportunities.',
#  'Points:\n1. Governments expected to increase emissions reduction commitments (Nationally Determined Contributions)\n2. Uncertainty surrounds whether governments will actually do this, or do so in a timely manner\n3. Possibility that governments may not meet or break commitments they have made.\n\nExplanation:\n1. The text mentions that governments are expected to increase their commitments to reduce emissions. This means they will need to take further steps to reduce their carbon footprint, such as investing in renewable energy or reducing dependency on fossil fuels.\n2. The text highlights uncertainty around whether or not governments will actually follow through on these commitments or do so in a timely manner. This implies that there may be political or economic barriers preventing timely and effective action.\n3. There is also the possibility that governments may not meet the commitments they have already made or may break them altogether. This may be due to changing political priorities, lack of resources, or other factors.',
#  '- The Company adopted the Executive Officer System in 2016 to clarify responsibility and establish a more flexible management structure.\n- The system separates management decision-making and supervisory functions from the execution of operations.\n- The delegation of authority to execute operations is being accelerated.\n- There are currently six executive officers, excluding those who also hold the position of Director.',
#  'Points:\n\n1. Climate-related risks and opportunities are important for the business.\n2. As an insurance company, understanding and managing risk is at the heart of what they do.\n3. Climate change poses material long-term impacts to the business. \n\nExplanation:\n\nThis paragraph mentions that the business recognizes the importance of climate-related risks and opportunities. As an insurance company, risk management is an essential task. Climate change poses material long-term impacts that they need to understand and manage.',
#  '- The emissions and energy reduction targets are detailed on page 29 of Metrics & Targets.\n- The reduction against target for emissions as of June 30, 2020 is being compared to the same period in 2013.',
#  "Points:\n\n1. Emerging risk is defined as a risk with large unknown components that may form beyond one year horizon.\n2. These risks can have a material impact on the Group's long term strategy, affect profitability and damage the Group's reputation.\n3. Existing management action plans are likely to be minimal due to the uncertain nature of these risks.\n4. Some high-level analysis or stress testing may have been carried out to assess and quantify the impact. \n\nExplanation:\n\n1. The text defines emerging risks as having large unknown components and forming beyond a one year horizon. This highlights the uncertainty and potential volatility of these risks.\n2. The impact of these risks can be significant, affecting the Group's long term strategy, profitability, and reputation. This underscores the need for effective risk management strategies.\n3. Due to the uncertainty surrounding these risks, existing management action plans are likely to be limited or inadequate.\n4. To better understand the potential impact of these risks, companies may carry out high-level analysis or stress testing to assess and quantify the potential effects on the business.",
#  "- PETRONAS PowerClean™ WS601 is an all-in-one well bore solution.\n- It is efficient and cost-effective.\n- The product helps oil and gas players continue to extract hydrocarbons with reduced impact on natural resources and the environment. \n\nExplanation: The paragraph highlights the benefits of PETRONAS PowerClean™ WS601. It is an all-in-one solution that provides efficient and cost-effective cleaning for the well bore. The product's main advantage is its ability to reduce the impact on our natural resources and the environment through the extraction of hydrocarbons.",
#  '1. AXA has acquired a 100% stake in Charter Ping An, the #5 non-life insurer in the Philippines.\n2. The acquisition cost €40 million.\n3. The acquisition allows AXA to expand its product range to include Property & Casualty insurance.\n4. AXA has extended its bancassurance partnership with GT Capital and Metrobank to include the distribution of Property & Casualty insurance products.',
#  "1. Enhancing durability, safety, quality, and performance of products.\n- This means that the company is working to make sure their products are of high quality and can be used for a long time without any issues, while also ensuring they are safe for consumers to use.\n\n2. Designing and developing various accessories.\n- The company is creating different accessories that can be used with their products, which may provide additional benefits to consumers.\n\n3. Pursuing cost-cutting and energy conservation initiatives.\n- The company is working to reduce costs and conserve energy in their operations, which can benefit both the environment and the company's bottom line.",
#  'Points:\n\n- Greenhouse gases are emitted both directly and indirectly.\n- Direct emissions (scope one) come from industrial businesses and fugitive emissions from coal mining.\n- Indirect emissions (scope two) mainly come from electricity used in operations.\n- Other indirect emissions (scope three) occur as a result of operations, such as air travel, but are not controlled by the company. \n\nExplanation:\n\nThe paragraph summarizes the sources of greenhouse gas emissions for the company, distinguishing between direct and indirect emissions. Direct emissions come from industrial activities and coal mining, while indirect emissions are mainly due to electricity use. Another type of indirect emission is acknowledged but is not controlled by the company and is estimated as emissions resulting from air travel.',
#  'Points:\n1. Short-term nature of business and annual re-pricing limit impact on general insurance liabilities.\n2. Risk mitigation provided by reinsurance arrangements.\n3. Increased physical effects of climate change can lead to uninsurable or unaffordable risks and perils over time.\n\nExplanation:\n1. The short-term nature of the business and the ability to re-price policies annually helps limit the impact of climate change on general insurance liabilities. This means that insurance companies can adjust their prices to reflect the impact of climate change on their policies.\n2. Reinsurance arrangements help insurance companies mitigate risks associated with climate change. Reinsurance is a way for insurance companies to transfer some of their risks to other companies in exchange for a premium.\n3. As climate change intensifies, the physical effects such as extreme weather events and rising sea levels could lead to more risks and perils that are either uninsurable or unaffordable. This means that some risks may be too costly for insurance companies to cover, or that it may be impossible to insure against certain risks altogether.',
#  'Points:\n- Company works with the business continuity team of its parent company.\n- A broad set of short, medium, and long-term business continuity risks are understood and managed.\n- Climate change is one component of these risks.\n\nExplanation: The company collaborates with the business continuity team of its parent company to manage various business risks in the short, medium, and long term. One of the risks is climate change, which is just a part of the wide-ranging risks that the team is responsible for managing.',
#  '- Linde faces claims, legal proceedings, and government investigations in the ordinary course of business.\n- These actions relate to environmental, tax, antitrust, and personal injury claims, among others.\n- These contingencies require management judgments to assess likely outcomes and establish liabilities.\n- Linde believes it records and discloses such contingencies appropriately and has reasonably estimated its liabilities.',
#  '- VtoV Employee Relief Fund provides aid for Verizon employees displaced from their homes for natural or personal emergency.\n- The aid includes grants for food, clothing, shelter, and other necessities during life-changing disasters.\n- VtoV has helped Verizon employees around the world. \n\nExplanation: The text highlights the VtoV Employee Relief Fund, which provides assistance to Verizon employees in times of natural or personal emergencies such as natural disasters, domestic violence, etc. The VtoV fund helps the employees by providing grants to use towards necessities like food, clothing, and shelter. The program has helped employees around the globe.',
#  "- The goal is to combat climate change and avoid economic risk for investors by excluding least energy efficient hydrocarbons and those that pose the greatest threat to the environment.\n- Projects and companies mainly focused on the following activities are turned down: oil sands production, oil extraction from the Arctic region (off-shore and on-shore production), shale gas or oil production involving excessive flaring or venting, and infrastructure projects mainly intended for the above-mentioned exclusion criteria.\n- Crédit Agricole S.A. aims to offset the company's entire direct carbon footprint until 2040.",
#  '- The Group calculates its direct emissions (Scope 1), indirect emissions from energy consumption (Scope 2) and other indirect emissions due to company activities that are not under its direct control (Scope 3).\n- In 2019, Atlantia Group produced approximately 355 thousand tonnes of carbon dioxide equivalent (Scope 1 + Scope 2).\n- Main sources of emissions were the production of electrical energy consumed (46%), fuel consumption for transport (21%), and fuel consumption for cogeneration (20%).\n- The remaining emissions come from consumption for heating and supply systems and emergency gensets.',
#  'Points: \n- Extreme weather events are a potential risk for the company. \n- Risks include loss or impairment of manufacturing sites, difficulty in procuring raw materials, and disrupted transportation. \n- The company has over 100 sites and a wide supplier network, which allows for some flexibility in adjusting production and sourcing. \n- Each site has a regularly reviewed and updated business continuity plan, which includes considerations for extreme weather event disruptions.',
#  '- Point: Increased severity/frequency of extreme weather events\n- Explanation: Refers to the worsening and more frequent occurrence of natural disasters such as hurricanes, floods, and wildfires.\n\n- Point: Loss or impairment of key manufacturing sites\n- Explanation: Refers to the damage or destruction of facilities where products are manufactured, leading to disruptions in supply chains and production.\n\n- Point: Inability to procure sufficient raw materials\n- Explanation: Refers to the difficulty in obtaining necessary resources due to disruptions in transportation or other barriers.\n\n- Point: Disruption to transportation of raw materials or finished goods\n- Explanation: Refers to difficulties in transporting necessary materials and products, leading to delays and potential shortages.\n\n- Point: Need for effective management and remedy in response to extreme events\n- Explanation: Highlighting the importance of taking swift and appropriate action to recover from natural disasters and other events that disrupt operations.',
#  "Points:\n1. Importance of six capitals for smooth operations and balanced scorecards \n2. Interrelated nature of the six capitals \n3. Compositions may change based on strategic focus \n\nExplanations: \n1. The six capitals (financial, manufactured, human, intellectual, social and relationship, and natural) are all necessary for success and maintain a balance between economic, social, and environmental factors. \n2. The six capitals are interconnected and changes in one can affect the others. \n3. Depending on the company's focus areas, the composition of the six capitals may shift to support sustainable growth.",
#  'Points:\n1. Energy-efficiency projects implemented\n2. Lighting control and HVAC upgrades\n3. Reduce energy costs\n4. Reduce greenhouse-gas footprint\n\nExplanations:\n1. The company has implemented energy-efficiency projects to be sustainable.\n2. The projects include lighting control and HVAC upgrades, which directly impact energy consumption.\n3. By reducing energy consumption, the company can save on energy costs.\n4. Reducing energy consumption also means the company can reduce its greenhouse-gas footprint, helping to combat climate change.',
#  "Points:\n1. A new climate-change voting policy has been created\n2. The policy will commence this year\n3. Voting against re-election of chairs of heavy emitting companies' boards with inadequate climate-change disclosures, management and emissions performance\n4. Includes consideration of how risks and opportunities presented by the low-carbon transition are managed\n5. Includes consideration of a company's own Scope 1 and 2 emissions\n\nExplanation:\n1. The text states that a new climate-change voting policy has been created.\n2. The policy will come into effect this year.\n3. The policy includes voting against the re-election of chairs of heavy emitting companies' boards that fail to disclose or manage climate-change and emissions performance properly.\n4. The voting policy will also take into account how companies manage risks and opportunities presented by the transition to a low-carbon economy.\n5. The policy will also consider a company's own Scope 1 and 2 emissions.",
#  '- Extreme weather events are becoming more frequent and severe due to climate change. \n- There will be increased intense tropical cyclones, more floods and large-area floods in many regions, higher sea levels, and a higher risk of drought in certain areas. \n- Certain areas such as the US Gulf Coast, China, Japan, and Vietnam are increasingly vulnerable to these extreme weather events and need to prepare accordingly.',
#  '1. Climate change is causing strain on the natural environment and water scarcity is becoming more visible.\n2. The Paris Agreement aims to limit temperature rise to below 2 degrees Celsius above pre-industrial levels.\n3. Obesity is a bigger health threat than hunger, but many populations struggle to find sufficient nourishment in their diets.',
#  '- Overarching risk management processes include considerations for climate change\n- More information on specific risk and opportunity management can be found in the Strategy section',
#  "- Stakeholders are concerned about pressing global issues related to corporate operations\n- These issues shape the sustainability agenda and initiatives\n- The agenda and initiatives manage external risks and present growth opportunities. \n\nExplanation: The paragraph highlights the importance of addressing global issues related to corporate operations in order to manage risks and exploit growth opportunities. The focus is on sustainability initiatives that can both mitigate risks and contribute to the business's bottom line.",
#  "Points:\n1. Increase in number and severity of weather events\n2. Fort McMurray had costliest natural catastrophe in Canadian history\n3. Changing weather patterns impact likelihood and severity of natural catastrophes\n4. Climate change poses a meaningful risk to business objectives\n\nExplanations:\n1. The paragraph acknowledges the increase in weather events that have occurred in recent years.\n2. The costliness of the Fort McMurray natural catastrophe highlights the risk of wildfires in Canada, which is likely to increase due to changing weather patterns.\n3. Changing weather patterns have an impact on natural catastrophes like wildfires, making them more likely and severe.\n4. The trend in climate change is a significant risk to businesses' ability to meet their objectives.",
#  "Points:\n- SASB materiality assessment tool was used in 2019 analysis\n- 28 themes were mapped using the tool, specifically in road and air transport, engineering, construction, and logistics sectors\n- SASB standards focus on investor perception\n- Materiality model is based on ESG issues' effects on financial conditions or operational performance of companies within a sector. \n\nExplanation: The Sustainability Accounting Standards Board (SASB) materiality assessment tool was used in the 2019 analysis, specifically in sectors such as road and air transport, engineering, construction, and logistics. The SASB standards focus on how ESG issues are perceived by investors. The materiality model is based on an assessment of the effects ESG issues can have on a company's financial conditions or operating performance within a particular sector.",
#  '- Manufacturing partners are subject to specific performance criteria measured and reviewed by Global Operations.\n- Strict control and inspection procedures are enforced in manufacturing partners and in our own factories.\n- Effectiveness of product-related standards is constantly measured through quality and material claim procedures.\n- Social and environmental performance criteria of suppliers are tracked through C-KPI and E-KPI tracking system.\n- Adherence to social and environmental standards is promoted throughout the supply chain.\n- Independent manufacturing partners list can be found on the website.',
#  "Points:\n1. BB DTVM performs asset screening based on socioenvironmental and corporate governance factors.\n2. BB DTVM uses its own ESG methodology that includes positive and negative screening.\n3. 55.12% of the total assets under management are subject to BB DTVM's ESG methodology.\n4. BB DTVM manages 10 investment funds with socioenvironmental characteristics.\n5. The total shareholders' equity of the 10 investment funds is R$ 3.15 billion as of December 2020. \n\nExplanation:\nBB DTVM is committed to sustainable and socially responsible investing. It applies asset screening that takes into account socioenvironmental and corporate governance aspects. The company uses its own ESG methodology that combines positive screening (selecting companies that demonstrate ESG excellence) and negative screening (excluding companies that cause harm). As a result, over 55% of BB DTVM's total assets under management are subject to this methodology. Additionally, BB DTVM has offered 10 investment funds that integrate socioenvironmental considerations. As of December 2020, the total shareholders' equity of these funds was R$ 3.15 billion.",
#  "- The Bank considers social and environmental outcomes in business decisions\n- The Bank does not lend to projects in the coal and coal seam gas sectors\n- The Bank's approach is based on pragmatism and avoiding broadening their footprint",
#  "Points: \n- Environmental and social issues can affect activities and revenue of clients \n- This can cause delays in payments or default \n- Higher risks in sectors with significant environmental and social impacts (e.g. mining and large hydroelectric plants) \n- Require comprehensive environmental and social due diligence and mitigating measures. \n\nExplanation: The text highlights the potential negative impact of environmental and social issues on both a company's activities and its clients' revenue. This can lead to payment delays or even defaults, especially in sectors with higher environmental and social impacts like mining and large hydroelectric plants. To address these risks, comprehensive environmental and social due diligence must be conducted, and measures put in place to mitigate any negative impacts.",
#  'Points: \n1. Goal is to achieve a decarbonized society \n- Explanation: This means reducing carbon emissions to zero. \n2. Energy-saving activities \n- Explanation: Upgrading equipment to be more energy-efficient, using renewable energy, and adopting next-generation energy sources are all ways to save energy. \n3. Development of products and services focused on decarbonization \n- Explanation: Creating and offering products or services which contribute to the reduction of carbon emissions.',
#  "Points:\n1. The company may not be able to offset the impact of climate change.\n2. Climate change legislation and regulation could affect CN's customers.\n3. It could make it difficult for CN's customers to produce products cost-effectively.\n4. Legal costs related to defending and resolving climate change litigation could increase. \n\nExplanations:\n1. The company may struggle to offset the impact of climate change, leading to potential negative consequences.\n2. CN's customers could be impacted directly by climate change legislation and regulation, making it difficult for them to operate effectively.\n3. It could become more expensive for CN's customers to produce their products, due to increased energy costs.\n4. Legal costs related to climate change litigation could increase, which would be an additional financial burden.",
#  '1. Reduction of energy consumption and GHG emissions.\nExplanation: The focus is on reducing energy consumption and greenhouse gas emissions.\n\n2. Mitigation of potential impacts from policy or regulatory actions.\nExplanation: By taking action to reduce emissions, the organization hopes to avoid potential negative impacts from government regulations or policies that may increase the price of carbon emissions.\n\n3. Actions being taken to achieve these goals.\nExplanation: The organization is implementing measures to reduce energy consumption and greenhouse gas emissions, with the aim of achieving their goals.',
#  "Points:\n1. Aim to build a sustainable business \n2. Make a positive difference for all \n3. Passion and integrity at the heart of everything \n4. Impact to be made now and in the future \n\nExplanations:\n1. The statement expresses a commitment to build a company that can operate sustainably, likely by minimizing waste, reducing emissions, and being energy-efficient.\n2. The business aims to make a positive impact, although there is no further information provided on what type of impact will be made and who or what the beneficiaries will be.\n3. Passion and integrity are values that guide the company's operations, likely indicating that ethical and moral considerations will underpin the business's decisions and practices.\n4. The company aims to make an impact in the present and the future, suggesting that the sustainability efforts are not just a short-term initiative but a long-term commitment.",
#  'Points: \n\n1. Goal of achieving carbon neutrality for corporate and own-retail sites by 2025. \n- Achieved by implementing on-site energy production, improving energy use efficiency, sourcing renewable energy, and balancing emissions through various partnership methods. \n2. Monitoring and improving water efficiencies at biggest consuming sites. \n3. Increasing environmental performance data coverage to strengthen sustainability foundation. \n4. Pushing implementation of eco-efficiency standards through the IMS at key sites.',
#  '1. Customers prefer environmentally friendly products.\n2. Shareholders prefer to invest in companies with a sustainable commitment.\n3. Financial institutions are investing in cleaner and greener investments.\n4. Investments are being made in technologies and infrastructure to address climate change.\n5. Operational costs are increasing to meet regulatory requirements for GHG emissions and climate change. \n\nExplanation: The paragraph identifies five key points relating to sustainability, environment, and climate change. These include changes in customer preference for eco-friendly products, shareholder inclination to support sustainable companies, financial institutions investing in green investments, investments in technologies and infrastructure to address climate change, and operational costs increasing to meet regulatory requirements for GHG emissions and climate change.',
#  'Points:\n- DNP Group taking steps towards a Decarbonized society\n- Steps include reducing consumption of CO2-generating energy, switching to low CO2 fuels, and introducing renewable energy sources\n\nExplanation:\nThe paragraph highlights the efforts of the DNP Group in aiming for a Decarbonized society. This involves reducing the amount of carbon dioxide (CO2) emissions. The DNP Group has taken steps towards this goal by decreasing the consumption of energy sources that generate CO2, such as fossil fuels. Additionally, they are transitioning to low CO2-emission fuels and incorporating renewable energy sources into their operations.',
#  "- CEO and Chairman of the Board sits on the SLC \nExplanation: The CEO and Chairman of the Board are members of the SLC (Senior Leadership Council).\n\n- Relevant climate-related items can be brought to the Company's Board of Directors \nExplanation: The CEO and Chairman of the Board can bring climate-related topics to the attention of the Company's Board of Directors.\n\n- Governance & Public Responsibility Committee oversees Corporate Citizenship efforts \nExplanation: The Governance & Public Responsibility Committee is responsible for overseeing the Company's Corporate Citizenship efforts, including those related to climate.",
#  "- In 2017, additional divestments were made from three fossil energy companies and four electrical power companies\n- One fossil energy company and three electrical power companies were reintroduced to the Fund's benchmark index because they no longer meet AP2's criteria for divesting companies in these sectors\n- The Fund has divested from equities and corporate bonds in 79 companies as a result of financial climate risks.",
#  '- The report presents data from manufacturing subsidiaries in the Group with more than 50% ownership. \n- The companies are guided to manage material matters sustainably. \n- Data from Da Vinci Group B.V. is not included as the acquisition was completed in mid-September and sustainability platforms have yet to be integrated.',
#  '- Company sold Canadian fossil fuel-based electricity generation business and Alberta PowerLine\n- Sales resulted in aggregate gain of $174 million in 2019',
#  'Points: \n1. Annual general meetings used to monitor and engage with companies \n2. Goal is to reduce risks from climate change \n3. Support climate change-related resolutions \n4. Collaborate with other investors when appropriate \n\nExplanation: The paragraph outlines the use of annual general meetings in monitoring and engaging with companies in the aspect of climate change. The goal is to reduce risks from climate change by supporting resolutions related to it. Additionally, collaboration with other investors is done when necessary.',
#  '- GHG emissions from electricity use were recalculated to include past years\n- Coefficients for fiscal years prior to tabulated years were used\n- Details listed on page 21. \n\nExplanation: The text provides information on the recalculation of greenhouse gas emissions from electricity use to include past years using coefficients from prior fiscal years. Additional details can be found on page 21.',
#  "Points:\n1. Banks facilitate financing through the issuance of green bonds.\n2. Analysis includes current lending, historical trends, and lending targets.\n3. 'No go projects' include lending to Adani Carmichael coal mine and Keystone XL pipeline.\n4. Investing in banks that lend to these projects will not be considered. \n\nExplanation:\nThe text discusses the criteria that are analyzed when assessing banks for sustainability and environmental impact. One of the ways in which banks facilitate financing is through the issuance of green bonds, and this is taken into account when evaluating their lending practices. The analysis also includes examining the bank's current lending, historical trends, and lending targets. In addition, there are certain projects, referred to as 'no go projects', such as lending to the Adani Carmichael coal mine and Keystone XL pipeline, which will result in the bank not being considered for investment. Thus, investing in banks that lend to these projects is not acceptable.",
#  '1. Companies with substantial emissions have a responsibility to reduce them.\n2. Delaying measures to reduce emissions can erode public confidence in the company.\n3. Delaying measures can increase environmental costs (such as CO2 credits) and impact financial performance. \n\nExplanation:\nThe paragraph highlights the importance of companies taking responsibility for their greenhouse gas emissions. It states that delaying measures to reduce emissions can have negative consequences such as eroding public trust, increasing environmental costs, and impacting financial performance.',
#  "- The tire industry is dealing with sustainable natural rubber and microplastics as major sustainability issues.\n- The natural rubber supply chain's sustainability issue is linked to human rights, environmental protection, transparent management, productivity, quality, and quality of life.\n- The Global Platform for Sustainable Natural Rubber (GPSNR) is a global platform for the sustainable supply chain of natural rubber for the supply chain and automotive industry. Hankook Tire & Technology is operating the GPSNR.\n- Hankook Tire & Technology is conducting research on microplastics for tire wear particles.\n- LG Chem is a major supplier for Hankook Tire & Technology's raw materials, and their sustainability efforts will positively impact the company's responsible sourcing policy.\n- Collaboration on sustainability among companies or industries is essential and desired.",
#  'Points:\n1. Company has been working to reduce environmental impact, including GHG emissions.\n2. Company continues to invest in operations, networks, and infrastructure to make them more resilient.\n3. These activities help manage risks, reduce operating costs, take advantage of renewable energy, and create potential competitive advantages. \n\nExplanation:\n1. The company has been taking action to reduce their environmental impact, with a specific focus on reducing greenhouse gas emissions.\n2. In addition, they are investing in operations, networks, and infrastructure to improve their resilience to environmental impacts.\n3. These actions not only help manage risks but also provide opportunities for cost savings, investment in renewable energy, and potential advantages over competitors in the marketplace.',
#  '- Insured losses in 2017 were higher than the previous year and 10-year average at US$ 135 billion, with hurricanes Harvey, Irma, and Maria accounting for over two-thirds of losses at US$ 92 billion.\n- Other significant losses were caused by California forest fires and earthquakes in Mexico.',
#  'Points:\n1. Confirmation of compliance.\n2. Status of continuous improvements and corrections.\n3. Audited sites required to review plans.\n\nExplanations:\n1. The paragraph mentions the confirmation of compliance with environmental targets.\n2. The status of continuous improvements and corrections being made towards achieving environmental targets is confirmed.\n3. Audited sites are required to review their plans when necessary.',
#  'Points:\n1. Organizational culture diagnosis is important for defining drivers.\n2. Only the Organizational Climate and Engagement Survey has been used since 2017. \n\nExplanation:\n1. The internal scenario of an organization, which includes organizational culture, is considered in the definition of the drivers. \n2. The organizational behavior area has decided to use only the Organizational Climate and Engagement Survey annually since 2017.',
#  "Points:\n1. Aim to report the weighted average carbon intensity of corporate bonds portfolio in 2021.\n2. Working towards obtaining a better understanding of emissions intensity in other significant portions of investment portfolio.\n3. Focus on data and methodological appropriateness to improve monitoring, management, and reporting in this area.\n\nExplanation:\nThe text highlights the company's goals for tracking carbon emissions. They aim to report the weighted average carbon intensity of their corporate bonds portfolio in 2021. Additionally, they are working to understand the emissions intensity of other significant portions of their investment portfolio where appropriate data and methodologies exist. The company is prioritizing the appropriateness of data and methodology to improve monitoring, management, and reporting in this area.",
#  'Points:\n1. Logistics aims to reduce cost, carbon footprint, and temperature deviation by driving freight to the ocean.\n2. New distribution pathways have been validated\n3. There is a greater opportunity to utilise ocean freight, especially into Middle Eastern markets.\n\nExplanation:\nThe paragraph discusses the focus of logistics on reducing cost, carbon footprint, and temperature deviation by driving freight to the ocean. It also mentions that many new distribution pathways have been validated, which provides greater opportunity to utilise ocean freight. The paragraph further emphasizes the potential of ocean freight in the emerging Middle Eastern markets.',
#  '- Utilities industry is focusing on decarbonization, digitalization, decentralization, and evolving customer demand.\n- Climate change concerns, evolving regulations, emission reduction targets, and government incentives are presenting opportunities for utility companies.\n- Natural gas and electric utilities are well positioned to capitalize on these trends.\n- Strategic priorities are to invest in lower emissions and cleaner energy solutions for customers while continuing to invest in the core business.',
#  'Points:\n- Significant resources have been devoted to developing risk management policies, procedures, and methods.\n- The risk management may not be fully effective in mitigating risk exposures in all economic market environments or against all types of risk.\n- There is a possibility of failing to identify or anticipate risks. \n\nExplanation:\nThe paragraph highlights the efforts put into developing risk management policies, but acknowledges that they may not be fully effective in all situations and against all types of risks. The final sentence emphasizes the need to be aware of the possibility of not identifying or anticipating risks.',
#  'Points: \n\n- Tropical cyclones pose a risk to coastal and inland infrastructure and can increase capital and operating costs for maintenance and repairs. \n- Investments are made every year to build resilience into operational infrastructure. \n- Lessons from previous storms, such as Superstorm Sandy, Hurricane Matthew, and Hurricane Michael, have led to steps to increase infrastructure resilience in affected and at-risk areas. \n- Steps to enhance infrastructure resilience include raising equipment, moving generators to higher levels, and installing underground fiber solutions. \n- Backup facility power systems are also being improved by adding generators to at-risk sites. \n- Regulatory requirements may result in higher operating costs than anticipated.',
#  '- Developed nations are expanding the global water management system\n- There may be losses due to trade barriers and regulations related to water footprint regulations, limiting exports. \n\nExplanation: The first point highlights that developed nations are applying a global water management system. The second point explains that limitations may occur in the form of losses due to trade barriers and regulations related to water footprint, which can limit exports.',
#  '- Corporate management sets strategic goals for reducing CO2 emissions.\n- The Product Steering Board monitors car fleet emissions in regulated markets and provides forecasts, taking into account vehicle electrification and legal requirements.\n- The Board of Management decides which measures to implement based on the evaluations of the PSB.\n- Price and volume control measures on the market side can affect the ability to achieve emissions targets in the short term.\n- These measures are discussed with the Board of Management as part of regular reporting on CO2 fleet compliance.',
#  'Points:\n1. There is an audit committee mentioned in the text \n2. The committee is composed of six members \n3. The chairman of the committee is Prof. Dr. Clemens Börsig \n4. All members are independent according to standards adopted by the Board of Directors and the NYSE \n\nExplanation: The text provides information about the audit committee and its members. It mentions that there are six members in the committee, and their names are listed. The chairman of the committee is Prof. Dr. Clemens Börsig. The text also notes that all members are independent according to standards established by the Board of Directors and the NYSE.',
#  "Points:\n1. Climate-related risks and opportunities are integrated into the risk management process at Daimler.\n2. Information for reporting to the Board of Management and Supervisory Board is passed on to Group Risk Management.\n\nExplanation: Daimler has incorporated climate-related risks and opportunities into its risk management process, and this information is shared with Group Risk Management through the company's segments. The Board of Management and Supervisory Board are kept informed through this reporting process.",
#  '-Targeted £500 million annual investment in low-carbon infrastructure from 2015-2020 \n-Associated carbon saving target of 100,000 CO2 tonnes annually \n-Signed £450 million of new investment into wind, solar, biomass and energy efficiency in 2016\n-Infrastructure Income Fund will deliver over 150,000 tonnes of CO2e savings annually \n-Aviva holds over £247 million in green bonds \n\nExplanation: The paragraph mentions a targeted investment of £500 million annually in low-carbon infrastructure from 2015-2020, with a corresponding carbon saving target of 100,000 CO2 tonnes annually. In 2016, the company signed £450 million in new investment into various green projects, including wind, solar, biomass, and energy efficiency. The Infrastructure Income Fund is also expected to deliver over 150,000 tonnes of CO2e savings each year once its projects become operational. Furthermore, Aviva holds over £247 million in green bonds.',
#  "Points:\n- Board manages strategic and operational risks with multiple levels of review.\n- Standing committees oversee specific risks and opportunities in their areas of responsibility, including climate-related ones.\n- Committee chairs update full Board on committee activities.\n- Board reviews risks associated with Verizon's strategic plan throughout the year.\n\nExplanation: The paragraph outlines how Verizon's Board manages risks, including climate-related ones, through standing committees and regular updates to the full Board. The Board also reviews risks associated with the company's strategic plan throughout the year.",
#  "Points:\n1. Identification of Nedbank's inherent risk before implementing controls for effective management of climate-related risks.\n2. Inherent risk profile is determined based on GHG emission industries and external threats.\n3. GHG emission industries pose a higher inherent risk depending on the nature of specific GHG emissions, and inherent risk increases as GHG emissions increase.\n4. External threats include changing weather patterns, client behavior and preferences, new technology and innovation, legislation, and risks.\n5. Nedbank may be exposed to risks due to activities of lending, investing, and the group's own operations.\n\nExplanation:\nNedbank has an inherent risk profile that is identified before implementing controls for effective management of climate-related risks. This inherent risk profile is determined based on GHG emission industries and external threats. GHG emission industries pose a higher inherent risk depending on the nature of specific GHG emissions, and inherent risk increases as GHG emissions increase. External threats include changing weather patterns, client behavior and preferences, new technology and innovation, legislation, and risks. Nedbank may be exposed to risks due to activities of lending, investing, and the group's own operations.",
#  "Points: \n1. Kempen Asset Management manages private banking discretionary management mandates and Evi Beleggen products.\n2. Total assets under management for these products amounted to €10.9 billion at the end of 2017.\n3. This amount is not included in Asset Management’s total AuM of €45.5 billion. \n\nExplanation: The paragraph states that Kempen Asset Management manages two different types of financial products, including private banking discretionary management mandates and Evi Beleggen products. At the end of 2017, the total assets under management for these products amounted to €10.9 billion. However, this amount is not included in Asset Management's total assets under management of €45.5 billion.",
# ...
#  "- Adverse weather like hurricanes and tropical storms can harm Offshore's financial performance.\n- Direct impacts may include lower throughput from harmed facilities and added costs for inspection and repairs.\n- Indirect impacts may include decreased throughput on Offshore's systems due to damaged third party production platforms, onshore processing plants, and pipelines.",
#  'Points:\n\n- Investment policies consider social, environmental, and governance objectives\n- Investment policies contribute to the transition to a low-carbon economy\n- Regulatory requirements could increase compliance costs and adversely affect business or investment value\n- Further regulations regarding energy transition or energy-related investments are possible.\n\nExplanation:\n\nThe paragraph discusses how investment policies take into account social, environmental, and governance objectives and contribute to a low-carbon economy. However, it also acknowledges that regulatory requirements, such as those related to energy transition and investments, can increase compliance costs and negatively impact business or investment value. Additionally, it notes that further regulations in these areas may be forthcoming.',
#  '- Company has growth ambition in derivatives, specialty chemicals, and solutions\n- Company established Optimal Group with Dow Chemical Company to produce performance and specialty chemicals\n- Company developed Integrated Aroma Ingredients Complex under joint venture company, BPC\n- Company invested in plants for 2-EHAcid and HR-PIB, the first of their kind in Southeast Asia, putting them ahead of the curve in the regional specialty chemicals market\n- Growth projects began commercial operations between 2016 and 2018.',
#  '- Canada has no licensed facilities for permanent disposal of used nuclear fuel or L&ILW.\n- OPG\'s proposed L&ILW DGR faces risks for safe long-term management of waste.\n- Risks are discussed under heading "Risks to Achieving Project Excellence – Deep Geologic Repository for Low and Intermediate Level Waste."',
#  'Points:\n1. Linde faces legal risks relating to product liability in the countries where it operates.\n2. Legal risks are higher in the United States due to class actions.\n3. The outcome of pending or future product and services proceedings or investigations cannot be predicted.\n4. Legal or regulatory judgments or settlements may result in significant losses, costs, and expenses for Linde. \n\nExplanation: The paragraph highlights the legal risks that Linde faces in relation to product liability, specifically in countries such as the United States. The unpredictability of the outcome of any pending or future proceedings or investigations poses a significant risk to the company, as legal or regulatory judgments or settlements may lead to significant financial losses for Linde.',
#  "- Group faces risks in its general insurance business\n- Not an exhaustive list of risks\n- Strategic risk identified in IAG's Risk Management Strategy\n- Strategic risk is the risk of not achieving corporate or strategic goals.",
#  '- Risk of corruption: The company is exposed to the risk of employees, third parties, or intermediaries engaging in corrupt activities that violate anticorruption laws.\n\n- Applicable legislation: This risk applies to both national and foreign laws related to anti-corruption, as well as any transnational legislation that may be applicable in the areas in which the company operates.',
#  '- Allocating emissions in the fossil fuel electricity supply chain between coal miners, transporters, and generators.\n- Investors who invest in fossil fuel companies should account properly for their role in the production of dangerous emissions from burning fossil fuels.',
#  '- Canadian Utilities has a track record of dividend growth for 49 consecutive years.\n- The company declared a first quarter dividend of 43.98 cents per share or $1.76 per share on an annualized basis.\n- Dividend growth is linked to sustainable earnings growth from regulated and long-term contracted investments.',
#  "Points:\n\n1. Environmental obligations and waste discharge quotas are regulated by Australian and foreign laws.\n2. Government agency audits and site inspections monitor CSL environmental performance.\n3. The EHS2 function is refining standards, processes, and data collection systems to meet new regulatory requirements. \n\nExplanations: \n\n1. The text states that laws related to environmental obligations and waste discharge quotas are regulated by both Australian and foreign governments. This implies that CSL must meet certain standards when it comes to waste management and environmental protection. \n2. The text mentions that government agencies are monitoring CSL's environmental performance through audits and inspections. This indicates that CSL must be accountable for their environmental impact and ensure they are following regulations. \n3. The EHS2 function is working to refine standards, processes, and data collection systems to meet new regulatory requirements. This implies that CSL is proactive in ensuring they are prepared for any changes in environmental regulations and are working to continuously improve their environmental practices.",
#  "- Purpose of financial statements: communicate Group's financial information to stakeholders, especially shareholders, investors, and lenders.\n- Financial statements: statement of profit or loss and other comprehensive income, statement of financial position, and statement of cash flows.\n- Function and relationships between financial statements to be explained for readers not familiar with accounting rules and financial expressions.\n- Comprehensive and authoritative definitions and explanations can be found in relevant accounting standards.",
#  'Points: \n1. Report 2019 (SR 2019) was requested by shareholders.\n2. Hard copies will be delivered once available.\n3. Consider the environment before printing or requesting printed copies.\n4. Environmental concerns affect humans, animals, and nations worldwide. \n\nExplanation: \n1. Shareholders requested Report 2019 (SR 2019). \n2. The hard copies of the report will be delivered to the company when they become available. \n3. It is requested to consider the environment before printing or requesting printed copies of the reports. \n4. The statement acknowledges the global impact of environmental concerns such as global warming, deforestation, and climate change on human, animal, and national levels.',
#  '- LG Chem considers climate change as its major management issue and will respond proactively.\n- Climate change risks and opportunity factors are categorized into regulatory, physical, and other aspects and LG Chem has established countermeasures for each issue.\n- LG Chem has developed a carbon neutral growth strategy as a top priority of their Sustainability strategy and is working on detailed action plans.',
#  'There are no important points in this text related to sustainability, environment, and climate change.',
#  'Points:\n1. DNP Group aims to minimize the impact of their businesses on the environment.\nExplanation: This means that the company wants to reduce their carbon footprint and negative impact on the environment.\n\n2. DNP Group supports biodiversity.\nExplanation: The company recognizes the importance of preserving and protecting different species of plants and animals.\n\n3. DNP Group complies with environmental laws and regulations.\nExplanation: The company follows the laws and regulations set by the government to ensure that they operate their businesses in an environmentally responsible way.\n\n4. DNP Group recognizes the relationship each of their business activities has with the environment.\nExplanation: The company understands that their business activities can have an impact on the environment and wants to take responsibility for minimizing that impact.\n\n5. DNP Group aims to create a sustainable society in a world with limited resources.\nExplanation: The company wants to ensure that their actions contribute to a sustainable future and that resources are used responsibly for future generations.',
#  "Points:\n1. The Bank performs liquidity stress testing on different scenarios.\n2. The scenarios consist of TD-specific events and market-wide stress events.\n3. The testing is designed to test the impact of risk factors related to the Bank's risk profile.\n4. Liquidity assessments are part of the Bank's EWST program.\n\nExplanation:\nThe paragraph discusses the Bank's liquidity stress testing and contingency funding plans. The Bank performs liquidity stress testing on various scenarios that are a mix of TD-specific events and market-wide stress events. These scenarios are designed to test the impact of risk factors related to the Bank's risk profile. Additionally, the Bank's EWST program includes liquidity assessments.",
#  'Points: \n\n1. Financing line for micro and small companies \n- A fund is available for micro and small companies\n\n2. With or without associated working capital \n- Can be used for investment projects with or without working capital\n\n3. Investment projects that provide generation or maintenance of employment and income \n- Projects must create or maintain jobs and income\n\n4.\xa0In urban areas \n- Projects must be in urban locations\n\n5. To enable sustainable development of micro and small companies \n- The goal is to support sustainable growth of these types of companies\n\n6. Aligned with Proger Urbano \n- Must be consistent with Proger Urbano, a government program aimed at promoting urban development.',
#  'Points:\n1. Reduction targets set to limit impact of operations on environment \n- This means that the company has goals in place to minimize their environmental impact by reducing carbon emissions and resource usage levels. \n\n2. Targets guide use of natural resources at various levels \n- The reduction targets are used as a guide for how natural resources are utilized within the company, from group level down to individual level.',
#  '- LG Chem is striving to contribute to the achievement of UN SDGs\n- The company focuses on SDGs relevant to its business models\n- LG Chem engages in various sustainability activities on specific targets related to the SDGs. \n\nExplanation: The paragraph states that LG Chem is committed to contributing to the achievement of the UN SDGs and has identified relevant SDGs based on their business models. They then engage in various sustainability activities to target specific goals.',
#  "Points:\n1. Indirect emissions are produced from operational activities we do not own or control.\n2. Indirect emissions include energy emissions from purchased electricity for treatment plants.\n3. Indirect emissions also come from activities such as business travel and waste disposal.\n\nExplanation:\nThis paragraph highlights the concept of indirect emissions, which are emissions that are not produced directly by a company's own operations, but instead from activities that they do not have full control over. The examples given include energy emissions from purchased electricity used to power treatment plants, as well as emissions from activities such as business travel and waste disposal.",
#  '1. The TCFD report data pertains to the year-ended December 31, 2020 unless otherwise noted.\n2. The Sustainability Report 2020 by Daimler will be available by March 29, 2021.\n3. The CDP Climate Change Questionnaire referenced in the report pertains to the reporting year 2019. \n\nExplanation: \nThe text provides three important pieces of information. Firstly, it clarifies that the TCFD report data is relevant to the year-ended December 31, 2020 unless otherwise specified. Secondly, it notes that the Sustainability Report 2020 by Daimler will be published on March 29, 2021 and its references will be available then. Lastly, it adds that the references to the CDP Climate Change Questionnaire in the report are related to the reporting year 2019.',
#  'Points:\n1. The bank plans to wind down its fossil fuel-related merger and acquisition advice.\n2. The bank will invest substantially in clean tech and banking services.\n3. The bank is preparing its first TCFD report.\n\nExplanation: The bank, as per the outcome mentioned, has decided to shift its focus towards sustainable investments by winding down its fossil fuel-related mergers and acquisitions. The bank plans to invest in clean tech and banking services in an effort to promote sustainability. Additionally, the bank will release its first-ever Task Force on Climate-Related Financial Disclosures (TCFD) report to reinforce its commitment to sustainable finance and environmental responsibility.',
#  "Points:\n- Banco do Brasil Foundation celebrated its 35th anniversary in 2020\n- The foundation has contributed to social transformation and sustainable development in Brazil\n- Focus on serving vulnerable segments of society from all regions and areas of Brazil. \n\nExplanation:\nThe text highlights the anniversary of Banco do Brasil Foundation and its contribution to sustainable development and social transformation in Brazil. The foundation's focus on vulnerable segments of society, regardless of their location within Brazil, is also emphasized.",
#  "1. Climate change leads to changes in environmental conditions such as temperature and precipitation levels, which can affect consumer demand for electricity.\n2. Physical effects of climate change, such as severe storms, floods, and other climatic events, can disrupt NRG's operations and supply chain, leading to increased costs.\n3. Meteorological changes could result in increased operating, capital, or power purchase costs.\n4. NRG's customers may also face significant costs in preparing for or responding to the physical impacts of climate change.\n5. Customers may need to increase the resiliency of their energy solutions and supply.",
#  'Points:\n1. Regulatory and fiscal environment essential for sustained returns in gold mining projects\n- A sound and certain regulatory and fiscal environment is necessary\n- Fluctuations in gold prices can be handled if it is in place\n- Returns can be achieved over 15 to 20-year average life of a project \n\n2. Legal and tax environments present challenges \n- Legal and tax environments in many jurisdictions affect long-term viability of mining sector \n- Becoming less conducive',
#  "- Gold Fields' global workforce has 20% women employees (2018: 19%)\n- Women hold 20% of management positions (2018: 18%)\n- Over half of female employees work in core mining activities\n- Gold Fields was included in the Bloomberg Gender-Equality Index\n- Identified gaps in the GEI include creating an inclusive culture, analyzing potential gender pay gaps, and creating a supportive work environment for women\n- Gold Fields aims to improve in these areas in the future.",
#  'Key Points: \n\n- Raw material and fuel prices fluctuate depending on supply-demand and foreign exchange rates. \n- Kyocera aims to improve negotiation power when procuring materials within the Kyocera Group. \n- Internal improvements and cost reduction measures are being implemented to absorb rising costs. \n- Long-term agreements with suppliers have been made to address future supply-demand balance.']

# %%
df['points'] = summarized_points

# %% [markdown]
# <h4>In the following step, the Zero Shot classifier is imported, the paragraphs are stored into variable X and the correct labels in variable Y. The labels are provided to the classifier and the classification process begins with the paragraphs being sent to the model.</h4>

# %%
from skllm import ZeroShotGPTClassifier

X = df['points']
Y = df['label']

candidate_labels = [
    "the provided text is not about sustainability, environment and climate change",
    "the provided text is about metrics for sustainability, environment and climate change",
    "the provided text is about strategy for sustainability, environment and climate change",
    "the provided text is about risk for sustainability, environment and climate change",
    "the provided text is about governance for sustainability, environment and climate change"
]


clf = ZeroShotGPTClassifier()
clf.fit(None, [candidate_labels])
preds = clf.predict(X)
# Out:
# 100%|██████████| 400/400 [10:42<00:00,  1.61s/it]

# %% [markdown]
# <h4>The predictions that are received, are stored in a variable, then they are stored both in numerical and textual representations in a Pandas DataFrame to further be compared and evaluated.</h4>

# %%
preds
# Out:
# ['the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about governance for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about governance for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about governance for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is about governance for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about governance for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about governance for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about governance for sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about governance for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about governance for sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about governance for sustainability, environment and climate change',
#  'the provided text is about governance for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about governance for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about governance for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about governance for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about governance for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about governance for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about governance for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about governance for sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about governance for sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about governance for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about governance for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about governance for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about governance for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about governance for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is about strategy for sustainability, environment and climate change',
#  'the provided text is about risk for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change',
#  'the provided text is about metrics for sustainability, environment and climate change',
#  'the provided text is not about sustainability, environment and climate change']

# %%
df['gpt-explanations'] = preds

# %%
labels = []

for label in preds:
  if label == "the provided text is not about sustainability, environment and climate change":
    labels.append(0)
  elif label == "the provided text is about metrics for sustainability, environment and climate change":
    labels.append(1)
  elif label == "the provided text is about strategy for sustainability, environment and climate change":
    labels.append(2)
  elif label == "the provided text is about risk for sustainability, environment and climate change":
    labels.append(3)
  elif label == "the provided text is about governance for sustainability, environment and climate change":
    labels.append(4)


labels
# Out:
# [2,
#  3,
#  0,
#  0,
#  3,
#  1,
#  3,
#  0,
#  4,
#  3,
#  0,
#  3,
#  1,
#  3,
#  0,
#  0,
#  0,
#  1,
#  3,
#  3,
#  3,
#  0,
#  3,
#  1,
#  3,
#  3,
#  1,
#  1,
#  4,
#  3,
#  1,
#  3,
#  2,
#  3,
#  1,
#  1,
#  1,
#  4,
#  3,
#  2,
#  3,
#  1,
#  2,
#  1,
#  1,
#  2,
#  4,
#  3,
#  1,
#  0,
#  4,
#  1,
#  4,
#  3,
#  1,
#  2,
#  3,
#  1,
#  0,
#  1,
#  1,
#  2,
#  3,
#  3,
#  0,
#  2,
#  0,
#  3,
#  1,
#  3,
#  3,
#  0,
#  3,
#  0,
#  3,
#  3,
#  1,
#  2,
#  3,
#  0,
#  3,
#  1,
#  0,
#  1,
#  0,
#  2,
#  1,
#  2,
#  3,
#  1,
#  0,
#  3,
#  1,
#  3,
#  3,
#  3,
#  1,
#  1,
#  0,
#  1,
#  4,
#  2,
#  0,
#  0,
#  2,
#  2,
#  3,
#  2,
#  1,
#  3,
#  3,
#  0,
#  3,
#  0,
#  1,
#  3,
#  3,
#  3,
#  0,
#  0,
#  2,
#  1,
#  0,
#  0,
#  2,
#  3,
#  3,
#  0,
#  3,
#  3,
#  4,
#  1,
#  1,
#  3,
#  1,
#  2,
#  1,
#  3,
#  4,
#  2,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  4,
#  4,
#  1,
#  3,
#  3,
#  3,
#  3,
#  1,
#  1,
#  1,
#  1,
#  1,
#  0,
#  1,
#  4,
#  3,
#  1,
#  3,
#  1,
#  1,
#  3,
#  3,
#  0,
#  1,
#  0,
#  2,
#  2,
#  1,
#  0,
#  1,
#  3,
#  3,
#  3,
#  4,
#  0,
#  4,
#  1,
#  1,
#  2,
#  0,
#  1,
#  2,
#  0,
#  0,
#  1,
#  3,
#  1,
#  2,
#  1,
#  1,
#  4,
#  1,
#  0,
#  2,
#  0,
#  3,
#  3,
#  0,
#  3,
#  0,
#  3,
#  1,
#  0,
#  4,
#  1,
#  1,
#  3,
#  0,
#  2,
#  1,
#  0,
#  3,
#  3,
#  1,
#  0,
#  0,
#  2,
#  1,
#  1,
#  1,
#  0,
#  1,
#  3,
#  1,
#  0,
#  0,
#  3,
#  3,
#  2,
#  0,
#  3,
#  4,
#  3,
#  1,
#  4,
#  2,
#  3,
#  2,
#  0,
#  2,
#  3,
#  4,
#  2,
#  3,
#  1,
#  3,
#  1,
#  1,
#  3,
#  0,
#  3,
#  0,
#  3,
#  3,
#  0,
#  1,
#  1,
#  1,
#  1,
#  1,
#  3,
#  0,
#  3,
#  3,
#  1,
#  3,
#  0,
#  1,
#  1,
#  1,
#  1,
#  2,
#  3,
#  1,
#  1,
#  0,
#  1,
#  0,
#  1,
#  0,
#  0,
#  3,
#  0,
#  1,
#  0,
#  3,
#  1,
#  2,
#  2,
#  3,
#  1,
#  1,
#  3,
#  0,
#  3,
#  3,
#  1,
#  0,
#  2,
#  1,
#  2,
#  1,
#  2,
#  3,
#  3,
#  3,
#  1,
#  3,
#  0,
#  3,
#  0,
#  2,
#  3,
#  1,
#  1,
#  2,
#  1,
#  0,
#  1,
#  0,
#  0,
#  2,
#  0,
#  2,
#  3,
#  1,
#  0,
#  0,
#  3,
#  0,
#  3,
#  1,
#  3,
#  0,
#  1,
#  2,
#  3,
#  1,
#  3,
#  0,
#  3,
#  1,
#  0,
#  0,
#  4,
#  0,
#  4,
#  3,
#  1,
#  1,
#  0,
#  0,
#  3,
#  1,
#  1,
#  3,
#  4,
#  3,
#  2,
#  1,
#  3,
#  2,
#  0,
#  3,
#  0,
#  2,
#  3,
#  4,
#  0,
#  3,
#  3,
#  3,
#  3,
#  1,
#  0,
#  4,
#  0,
#  2,
#  2,
#  0,
#  2,
#  3,
#  2,
#  1,
#  2,
#  1,
#  1,
#  2,
#  2,
#  3,
#  0,
#  1,
#  0]

# %%
df['gpt-label'] = labels

# %%
df
# Out:
#                                                   text  label  gpt-label  \
# 0    Sustainable strategy ‘red lines’ For our susta...      2          2
# 1    Verizon’s environmental, health and safety man...      3          3
# 2    In 2019, the Company closed a series of transa...      2          0
# 3    In December 2020, the AUC approved the Electri...      2          0
# 4    Finally, there is a reputational risk linked t...      2          3
# ..                                                 ...    ...        ...
# 395  In 2020, Banco do Brasil Foundation celebrated...      2          2
# 396  Climate change is producing changes in weather...      2          3
# 397  A sound and certain regulatory and fiscal envi...      0          0
# 398  Across our global workforce, 20% of Gold Field...      0          1
# 399  The purchase price of these raw materials and ...      0          0
#
#                                       gpt-explanations  \
# 0    the provided text is about strategy for sustai...
# 1    the provided text is about risk for sustainabi...
# 2    the provided text is not about sustainability,...
# 3    the provided text is not about sustainability,...
# 4    the provided text is about risk for sustainabi...
# ..                                                 ...
# 395  the provided text is about strategy for sustai...
# 396  the provided text is about risk for sustainabi...
# 397  the provided text is not about sustainability,...
# 398  the provided text is about metrics for sustain...
# 399  the provided text is not about sustainability,...
#
#                                                 points
# 0    Points:\n1. Sustainable strategy range\n2. Pro...
# 1    Points:\n1. Verizon has an environmental, heal...
# 2    Points:\n- The Company sold its Canadian fossi...
# 3    Points:\n- AUC approved deferral of distributi...
# 4    - Reputational risk for oil companies \n- Poss...
# ..                                                 ...
# 395  Points:\n- Banco do Brasil Foundation celebrat...
# 396  1. Climate change leads to changes in environm...
# 397  Points:\n1. Regulatory and fiscal environment ...
# 398  - Gold Fields' global workforce has 20% women ...
# 399  Key Points: \n\n- Raw material and fuel prices...
#
# [400 rows x 5 columns]

# %%
df['gpt-label'].value_counts()
# Out:
# 3    123
# 1    113
# 0     87
# 2     53
# 4     24
# Name: gpt-label, dtype: int64

# %% [markdown]
# <h4>The DataFrame is also stored on Google Drive, for later viewing and analysis. This step can be skipped.</h4>

# %%
df.to_csv("/content/drive/MyDrive/DS-Environment-Project/ChatGPT Results/scikit-llm/chatgpt_climate_tcfd_recommendations_scikit_llm.csv",index=False)

# %% [markdown]
# <h4>In the following section, the predicted labels are compared to the actual labels and the results are displayed.</h4>
# <hr>
# <h4>In the first row of the output, three metrics are displayed in the following order: <h6>(precision, recall, fscore, support - optional, may be none)</h6></h4>
# <h4>In the second row, only the F1 Score is displayed, for better clarity.</h4>
# <h4>In the third row the confusion matrix is displayed.</h4>
# <h4>In the fourth row the whole classification report is displayed, with the metrics per class: precision, recall, f1 score and support; the accuracy, per class and overall and the macro and micro averages of each metric.</h4>

# %%
# calculate the precision and f1 score for df columns label and prediction
from sklearn.metrics import precision_recall_fscore_support,f1_score
sent_col = 'gpt-label'
print(precision_recall_fscore_support(df['label'], df[sent_col], average='macro'))

# f1 score only
print(f1_score(df['label'], df[sent_col], average='macro'))

# confusion matrix
from sklearn.metrics import confusion_matrix
print(confusion_matrix(df['label'], df[sent_col]))

# performnce report

from sklearn.metrics import classification_report
print(classification_report(df['label'], df[sent_col]))
# Out:
# (0.45759588424961695, 0.5132752804362666, 0.4198191064265232, None)
# 0.4198191064265232
# [[51  2  2 21  4]
#  [ 5 38  5  1  0]
#  [30 56 40 63  8]
#  [ 0 14  2 29  3]
#  [ 1  3  4  9  9]]
#               precision    recall  f1-score   support
#
#            0       0.59      0.64      0.61        80
#            1       0.34      0.78      0.47        49
#            2       0.75      0.20      0.32       197
#            3       0.24      0.60      0.34        48
#            4       0.38      0.35      0.36        26
#
#     accuracy                           0.42       400
#    macro avg       0.46      0.51      0.42       400
# weighted avg       0.58      0.42      0.40       400
